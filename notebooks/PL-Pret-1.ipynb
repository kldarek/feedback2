# %%
# pretraining
DEBUG = False

# %%
EXP = 'PLpret1'

# %%
import torch
from torch import nn
from torch.nn import functional as F
from torch.utils.data import DataLoader
import pytorch_lightning as pl

import pandas as pd
import numpy as np
import random
import re
import itertools
import argparse

from torch.utils.data import Dataset
import spacy
import ast
from sklearn.model_selection import StratifiedKFold, GroupKFold, KFold

import pickle
import transformers
from transformers import AutoConfig, AutoModel, AutoTokenizer, get_linear_schedule_with_warmup
import warnings
from torch.optim import Adam, SGD, AdamW

import wandb
from pytorch_lightning.loggers import WandbLogger

# %%
pl.seed_everything(42, workers=True)
# Out:
# Global seed set to 42
# 42

# %%
class MyDataset(Dataset):
    def __init__(self, df, tokenizer, max_len=1024, stage='train', rand_prob=0.1, lowup_proba=0.0, swap_proba=0.0):
        self.df = df
        self.max_len = max_len
        self.tokenizer = tokenizer
        self.mask_token = tokenizer.convert_tokens_to_ids(tokenizer.mask_token)
        self.stage = stage
        self.rand_prob = rand_prob
        self.lowup_proba = lowup_proba
        self.swap_proba = swap_proba

        self.essay_id = df['essay_id'].values
        self.input_ids = df['input_ids'].values
        self.attention_mask = df['attention_mask'].values
        self.token_class_labels = df['token_class_labels'].values
        self.token_scores_labels = df['token_scores_labels'].values
        self.token_examples_mapping = df['token_examples_mapping'].values
        self.examples_scores = df['examples_scores'].values
        self.examples_classes = df['examples_classes'].values    
        
    def __getitem__(self, idx):
        essay_id = self.essay_id[idx]

        token_examples_mapping = self.token_examples_mapping[idx]
        examples_scores = self.examples_scores[idx]
        examples_classes = self.examples_classes[idx]

#         token_examples_mapping = torch.tensor(token_examples_mapping, dtype=torch.long)
#         examples_scores = torch.tensor(examples_scores + [-1] * (40 - len(examples_scores)), dtype=torch.long)
#         examples_classes = torch.tensor(examples_classes + [-1] * (40 - len(examples_classes)), dtype=torch.long)
        
        input_ids = self.input_ids[idx]
        attention_mask = self.attention_mask[idx]
        token_class_labels = self.token_class_labels[idx]
        token_scores_labels = self.token_scores_labels[idx]

#         input_ids = torch.tensor(input_ids, dtype=torch.long)
#         attention_mask = torch.tensor(attention_mask, dtype=torch.long)
#         token_class_labels = torch.tensor(token_class_labels, dtype=torch.long)
#         token_scores_labels = torch.tensor(token_scores_labels, dtype=torch.long)

#         if self.stage == 'train':
#             ix = torch.rand(size=(len(input_ids),)) < self.rand_prob
#             input_ids[ix] = self.mask_token
        
        return {
            "input_ids": input_ids,
            "attention_mask": attention_mask,
            "token_class_labels": token_class_labels,
            "token_scores_labels": token_scores_labels,
            "token_examples_mapping": token_examples_mapping,
            "examples_scores": examples_scores,
            "examples_classes": examples_classes
        }

    def __len__(self):
        return len(self.df)

# %%
emb_dim = 32
pooler_dropout = 0.1

# %%
from transformers.activations import GELUActivation

class Pooler(nn.Module):
    def __init__(self, hidden_size, dropout):
        super().__init__()
        self.dense = nn.Linear(hidden_size, hidden_size)
        self.act = GELUActivation()
        self.dropout = nn.Dropout(dropout)

    def forward(self, features):
        # We "pool" the model by simply taking the hidden state corresponding
        # to the first token.

        features = self.dropout(features)
        features = self.dense(features)
        features = self.act(features)
        return features

# %%
class MyModule(pl.LightningModule):
    def __init__(self, lr, model_checkpoint, num_classes, num_classes_class, emb_dim):
        super().__init__()
        self.lr = lr
        self.num_classes = num_classes
        self.num_classes_class = num_classes_class
        self.emb_dim = emb_dim
        self.name = model_checkpoint
        self.pad_idx = 1 if "roberta" in self.name else 0
        config = AutoConfig.from_pretrained(model_checkpoint, output_hidden_states=True)
        self.longformer = AutoModel.from_pretrained(model_checkpoint, config=config)
        self.nb_features = config.hidden_size
        self.logits = nn.Linear(self.nb_features, num_classes)
        self.pooler_class = Pooler(self.nb_features, pooler_dropout)
        self.pooler_scores = Pooler(self.nb_features, pooler_dropout)
        self.pooler = Pooler(self.nb_features + self.emb_dim, pooler_dropout)
        self.example_logits = nn.Linear(self.nb_features + self.emb_dim, num_classes)
        self.class_logits = nn.Linear(self.nb_features, num_classes_class)  
        transformers.logging.set_verbosity_error()
        self.embedding = nn.Embedding(num_classes_class, emb_dim, max_norm=True)
    
    def load_model(self, path):
        self.load_state_dict(torch.load(path, map_location='cuda:0'), strict=False)
        print('Model Loaded!')
    
    def configure_optimizers(self):
        no_decay = ["bias", "LayerNorm.bias", "LayerNorm.weight"]
        optimizer_parameters = [
            {'params': [p for n, p in self.named_parameters() if (not any(nd in n for nd in no_decay)) and \
                       ('deberta' in n)],
             'lr': self.lr, 'weight_decay': 0.01},
            {'params': [p for n, p in self.named_parameters() if (any(nd in n for nd in no_decay)) and \
                       ('deberta' in n)],
             'lr': self.lr, 'weight_decay': 0.0},
            {'params': [p for n, p in self.named_parameters() if (not any(nd in n for nd in no_decay)) and \
                       ('deberta' not in n)],
             'lr': self.lr * 10, 'weight_decay': 0.01},
            {'params': [p for n, p in self.named_parameters() if (any(nd in n for nd in no_decay)) and \
                       ('deberta' not in n)],
             'lr': self.lr * 10, 'weight_decay': 0.0},
        ]
        optimizer = AdamW(optimizer_parameters, lr=self.lr)
        scheduler = get_linear_schedule_with_warmup(
            optimizer,
            num_warmup_steps=100,
            num_training_steps=self.trainer.estimated_stepping_batches,
        )
        scheduler = {"scheduler": scheduler, "interval": "step", "frequency": 1}
        return [optimizer], [scheduler]
                
    def training_step(self, train_batch, batch_idx):
        input_ids, attention_mask, token_scores_labels, token_examples_mapping, \
        examples_scores, examples_classes, token_class_labels = \
            train_batch["input_ids"], train_batch["attention_mask"], train_batch["token_scores_labels"], \
            train_batch['token_examples_mapping'], train_batch['examples_scores'], \
            train_batch['examples_classes'], train_batch['token_class_labels']
        
        hidden_states = self.longformer(
            input_ids,
            attention_mask=attention_mask,
        )[-1]
        features = hidden_states[-1]
        class_logits = self.class_logits(self.pooler_class(features))
        class_loss = F.cross_entropy(class_logits.view(-1, self.num_classes_class), token_class_labels.view(-1))
        self.log('train_classes_loss', class_loss)
        return class_loss
        
    def validation_step(self, val_batch, batch_idx):
        input_ids, attention_mask, token_scores_labels, token_examples_mapping, \
        examples_scores, examples_classes, token_class_labels = \
            val_batch["input_ids"], val_batch["attention_mask"], val_batch["token_scores_labels"], \
            val_batch['token_examples_mapping'], val_batch['examples_scores'], val_batch['examples_classes'], \
            val_batch['token_class_labels']
        hidden_states = self.longformer(
            input_ids,
            attention_mask=attention_mask,
        )[-1]
        features = hidden_states[-1]
        class_logits = self.class_logits(features)
        class_loss = F.cross_entropy(class_logits.view(-1, self.num_classes_class), token_class_labels.view(-1))
        self.log('val_class_loss', class_loss)
        return {"val_class_loss": class_loss}

# %%
class Collate:
    def __init__(self, tokenizer):
        self.tokenizer = tokenizer

    def __call__(self, batch):
        output = dict()
        output["input_ids"] = [sample["input_ids"] for sample in batch]
        output["attention_mask"] = [sample["attention_mask"] for sample in batch]
        output["token_class_labels"] = [sample["token_class_labels"] for sample in batch]
        output["token_scores_labels"] = [sample["token_scores_labels"] for sample in batch]
        output["token_examples_mapping"] = [sample["token_examples_mapping"] for sample in batch]
        output["examples_scores"] = [sample["examples_scores"] for sample in batch]
        output["examples_classes"] = [sample["examples_classes"] for sample in batch]

        # calculate max token length of this batch
        batch_max = max([len(ids) for ids in output["input_ids"]])
        batch_max_ex = max([len(sco) for sco in output["examples_scores"]])

        # add padding
        if self.tokenizer.padding_side == "right":
            output["input_ids"] = [s + (batch_max - len(s)) * [self.tokenizer.pad_token_id] for s in output["input_ids"]]
            output["attention_mask"] = [s + (batch_max - len(s)) * [0] for s in output["attention_mask"]]
            output["token_class_labels"] = [s + (batch_max - len(s)) * [-100] for s in output["token_class_labels"]]
            output["token_scores_labels"] = [s + (batch_max - len(s)) * [-100] for s in output["token_scores_labels"]]
            output["token_examples_mapping"] = [s + (batch_max - len(s)) * [-1] for s in output["token_examples_mapping"]]
            output["examples_scores"] = [s + (batch_max_ex - len(s)) * [-1] for s in output["examples_scores"]]
            output["examples_classes"] = [s + (batch_max_ex - len(s)) * [-1] for s in output["examples_classes"]]

        else:
            output["input_ids"] = [(batch_max - len(s)) * [self.tokenizer.pad_token_id] + s for s in output["input_ids"]]
            output["attention_mask"] = [(batch_max - len(s)) * [0] + s for s in output["attention_mask"]]
            output["token_class_labels"] = [(batch_max - len(s)) * [-100] + s for s in output["token_class_labels"]]
            output["token_scores_labels"] = [(batch_max - len(s)) * [-100] + s for s in output["token_scores_labels"]]
            output["token_examples_mapping"] = [(batch_max - len(s)) * [-1] + s for s in output["token_examples_mapping"]]
            output["examples_scores"] = [(batch_max_ex - len(s)) * [-1] + s for s in output["examples_scores"]]
            output["examples_classes"] = [(batch_max_ex - len(s)) * [-1] + s for s in output["examples_classes"]]

        # convert to tensors
        output["input_ids"] = torch.tensor(output["input_ids"], dtype=torch.long)
        output["attention_mask"] = torch.tensor(output["attention_mask"], dtype=torch.long)
        output["token_class_labels"] = torch.tensor(output["token_class_labels"], dtype=torch.long)
        output["token_scores_labels"] = torch.tensor(output["token_scores_labels"], dtype=torch.long)
        output["token_examples_mapping"] = torch.tensor(output["token_examples_mapping"], dtype=torch.long)
        output["examples_scores"] = torch.tensor(output["examples_scores"], dtype=torch.long)
        output["examples_classes"] = torch.tensor(output["examples_classes"], dtype=torch.long)

        return output

# %%
from pytorch_lightning.callbacks import ModelCheckpoint

model_checkpoint = 'microsoft/deberta-v3-large'
tokenizer = AutoTokenizer.from_pretrained(model_checkpoint)
collate_fn = Collate(tokenizer)
bs = 2
project = 'fbck'
seed = 42
randmask_proba = 0.1
lr = 3e-6
epochs = 1 if DEBUG else 2
num_classes = 3
num_classes_class = 8

# %%
import pickle
with open('pretraining-deberta-v3-large-nbroad.pickle', 'rb') as handle:
    pdf = pickle.load(handle)

# %%
if DEBUG: pdf = pdf.sample(n=200, random_state=4)

# %%
def pretrain(fold=0):
    
    print()
    print('*' * 100)
    print(f'Training fold {fold}')
    print('*' * 100)
    
    df_train = pdf[pdf.fold == -1].reset_index(drop=True)
    df_valid = pdf[pdf.fold != -1].reset_index(drop=True)

    tags = ['debug'] if DEBUG else ['PL', 'train', f'fold_{fold}']

    run = wandb.init(project=project, 
                       name=f"{EXP}_fold_{fold}",
                       tags=tags,
                       group=f"{EXP}")
    run.log_code()

    pl.seed_everything(seed)


    train_dataset = MyDataset(
        df_train,
        tokenizer,
        stage='train',
        rand_prob=randmask_proba
    )

    valid_dataset = MyDataset(
        df_valid,
        tokenizer,
        stage='valid',
        rand_prob=randmask_proba
    )

    train_loader = DataLoader(train_dataset,
                              batch_size=bs,
                              shuffle=True,
                              collate_fn=collate_fn,
                              num_workers=4, pin_memory=True, drop_last=True)

    val_loader = DataLoader(valid_dataset,
                              batch_size=1,
                              shuffle=False,
                              collate_fn=collate_fn,
                              num_workers=4, pin_memory=True, drop_last=False)

    warnings.filterwarnings("ignore")

    model = MyModule(lr=lr,
                     model_checkpoint=model_checkpoint, 
                     num_classes=num_classes,
                     num_classes_class=num_classes_class,
                     emb_dim=emb_dim,
                    )

    wandb_logger = WandbLogger(project=project)

    checkpoint_callback = ModelCheckpoint(
        save_top_k=1,
        monitor="val_class_loss",
        mode="min",
        dirpath=f"../output/{EXP}/{fold}",
        filename="feedback-{epoch:02d}-{val_class_loss:.2f}",
    )

    trainer = pl.Trainer(precision=16, 
                         accelerator="gpu", devices=1, max_epochs=epochs,
                         log_every_n_steps=100, logger=wandb_logger,
                         default_root_dir=f"../output/{EXP}",
                         callbacks=[checkpoint_callback],
                         accumulate_grad_batches=2,
                         )

    trainer.fit(model, train_loader, val_loader)

    wandb.finish()

# %%
pretrain()
# Out:
# ****************************************************************************************************
# Training fold 0
# ****************************************************************************************************
# Changes to your `wandb` environment variables will be ignored because your `wandb` session has already started. For more information on how to modify your settings with `wandb.init()` arguments, please refer to <a href="https://wandb.me/wandb-init" target="_blank">the W&B docs</a>.
# wandb version 0.13.1 is available!  To upgrade, please run:
#  $ pip install wandb --upgrade
# Tracking run with wandb version 0.12.21
# Run data is saved locally in <code>/home/darek/projects/fbck/notebooks/wandb/run-20220813_232154-3qajnk27</code>
# Syncing run <strong><a href="https://wandb.ai/darek/fbck/runs/3qajnk27" target="_blank">PLpret1_fold_0</a></strong> to <a href="https://wandb.ai/darek/fbck" target="_blank">Weights & Biases</a> (<a href="https://wandb.me/run" target="_blank">docs</a>)<br/>
# Global seed set to 42
# Using 16bit native Automatic Mixed Precision (AMP)
# GPU available: True, used: True
# TPU available: False, using: 0 TPU cores
# IPU available: False, using: 0 IPUs
# HPU available: False, using: 0 HPUs
# LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
# Loading `train_dataloader` to estimate number of stepping batches.
#
#   | Name           | Type           | Params
# --------------------------------------------------
# 0 | longformer     | DebertaV2Model | 434 M
# 1 | logits         | Linear         | 3.1 K
# 2 | pooler_class   | Pooler         | 1.0 M
# 3 | pooler_scores  | Pooler         | 1.0 M
# 4 | pooler         | Pooler         | 1.1 M
# 5 | example_logits | Linear         | 3.2 K
# 6 | class_logits   | Linear         | 8.2 K
# 7 | embedding      | Embedding      | 256
# --------------------------------------------------
# 437 M     Trainable params
# 0         Non-trainable params
# 437 M     Total params
# 874.485   Total estimated model params size (MB)
# Epoch 0:  58%|███████████████▌           | 5701/9892 [24:18<17:51,  3.91it/s, loss=0.265, v_num=nk27]
# Validation: 0it [00:00, ?it/s]
# Validation:   0%|                                                           | 0/4191 [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|                                              | 0/4191 [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|                                      | 1/4191 [00:00<15:14,  4.58it/s]
# Epoch 0:  58%|███████████████▌           | 5702/9892 [24:18<17:52,  3.91it/s, loss=0.265, v_num=nk27]
# Validation DataLoader 0:   0%|                                      | 2/4191 [00:00<10:29,  6.65it/s]
# Epoch 0:  58%|███████████████▌           | 5703/9892 [24:18<17:51,  3.91it/s, loss=0.265, v_num=nk27]
# Epoch 0:  58%|███████████████▌           | 5704/9892 [24:19<17:51,  3.91it/s, loss=0.265, v_num=nk27]
# Validation DataLoader 0:   0%|                                      | 4/4191 [00:00<10:50,  6.44it/s]
# Epoch 0:  58%|███████████████▌           | 5705/9892 [24:19<17:50,  3.91it/s, loss=0.265, v_num=nk27]
# Epoch 0:  58%|███████████████▌           | 5706/9892 [24:19<17:50,  3.91it/s, loss=0.265, v_num=nk27]
# Validation DataLoader 0:   0%|                                      | 6/4191 [00:00<08:09,  8.55it/s]
# Epoch 0:  58%|███████████████▌           | 5707/9892 [24:19<17:50,  3.91it/s, loss=0.265, v_num=nk27]
# Epoch 0:  58%|███████████████▌           | 5708/9892 [24:19<17:49,  3.91it/s, loss=0.265, v_num=nk27]
# Validation DataLoader 0:   0%|                                      | 8/4191 [00:00<07:15,  9.60it/s]
# Epoch 0:  58%|███████████████▌           | 5709/9892 [24:19<17:49,  3.91it/s, loss=0.265, v_num=nk27]
# Epoch 0:  58%|███████████████▌           | 5710/9892 [24:19<17:49,  3.91it/s, loss=0.265, v_num=nk27]
# Validation DataLoader 0:   0%|                                     | 10/4191 [00:01<09:36,  7.26it/s]
# Epoch 0:  58%|███████████████▌           | 5711/9892 [24:19<17:48,  3.91it/s, loss=0.265, v_num=nk27]
# Epoch 0:  58%|███████████████▌           | 5712/9892 [24:20<17:48,  3.91it/s, loss=0.265, v_num=nk27]
# Validation DataLoader 0:   0%|                                     | 12/4191 [00:01<09:43,  7.16it/s]
# Epoch 0:  58%|███████████████▌           | 5713/9892 [24:20<17:48,  3.91it/s, loss=0.265, v_num=nk27]
# Epoch 0:  58%|███████████████▌           | 5714/9892 [24:20<17:47,  3.91it/s, loss=0.265, v_num=nk27]
# Validation DataLoader 0:   0%|                                     | 14/4191 [00:01<08:11,  8.51it/s]
# Epoch 0:  58%|███████████████▌           | 5715/9892 [24:20<17:47,  3.91it/s, loss=0.265, v_num=nk27]
# Epoch 0:  58%|███████████████▌           | 5716/9892 [24:20<17:46,  3.91it/s, loss=0.265, v_num=nk27]
# Validation DataLoader 0:   0%|▏                                    | 16/4191 [00:01<07:18,  9.52it/s]
# Epoch 0:  58%|███████████████▌           | 5717/9892 [24:20<17:46,  3.91it/s, loss=0.265, v_num=nk27]
# Epoch 0:  58%|███████████████▌           | 5718/9892 [24:20<17:46,  3.91it/s, loss=0.265, v_num=nk27]
# Validation DataLoader 0:   0%|▏                                    | 18/4191 [00:02<06:25, 10.83it/s]
# Epoch 0:  58%|███████████████▌           | 5719/9892 [24:20<17:45,  3.92it/s, loss=0.265, v_num=nk27]
# Epoch 0:  58%|███████████████▌           | 5720/9892 [24:20<17:45,  3.92it/s, loss=0.265, v_num=nk27]
# Validation DataLoader 0:   0%|▏                                    | 20/4191 [00:02<06:11, 11.21it/s]
# Epoch 0:  58%|███████████████▌           | 5721/9892 [24:20<17:45,  3.92it/s, loss=0.265, v_num=nk27]
# Epoch 0:  58%|███████████████▌           | 5722/9892 [24:20<17:44,  3.92it/s, loss=0.265, v_num=nk27]
# Validation DataLoader 0:   1%|▏                                    | 22/4191 [00:02<06:02, 11.50it/s]
# Epoch 0:  58%|███████████████▌           | 5723/9892 [24:21<17:44,  3.92it/s, loss=0.265, v_num=nk27]
# Epoch 0:  58%|███████████████▌           | 5724/9892 [24:21<17:43,  3.92it/s, loss=0.265, v_num=nk27]
# Validation DataLoader 0:   1%|▏                                    | 24/4191 [00:02<05:44, 12.11it/s]
# Epoch 0:  58%|███████████████▋           | 5725/9892 [24:21<17:43,  3.92it/s, loss=0.265, v_num=nk27]
# Epoch 0:  58%|███████████████▋           | 5726/9892 [24:21<17:43,  3.92it/s, loss=0.265, v_num=nk27]
# Validation DataLoader 0:   1%|▏                                    | 26/4191 [00:02<05:32, 12.53it/s]
# Epoch 0:  58%|███████████████▋           | 5727/9892 [24:21<17:42,  3.92it/s, loss=0.265, v_num=nk27]
# Epoch 0:  58%|███████████████▋           | 5728/9892 [24:21<17:42,  3.92it/s, loss=0.265, v_num=nk27]
# Validation DataLoader 0:   1%|▏                                    | 28/4191 [00:02<06:44, 10.30it/s]
# Epoch 0:  58%|███████████████▋           | 5729/9892 [24:21<17:42,  3.92it/s, loss=0.265, v_num=nk27]
# Epoch 0:  58%|███████████████▋           | 5730/9892 [24:21<17:41,  3.92it/s, loss=0.265, v_num=nk27]
# Validation DataLoader 0:   1%|▎                                    | 30/4191 [00:03<06:18, 10.99it/s]
# Epoch 0:  58%|███████████████▋           | 5731/9892 [24:21<17:41,  3.92it/s, loss=0.265, v_num=nk27]
# Epoch 0:  58%|███████████████▋           | 5732/9892 [24:21<17:40,  3.92it/s, loss=0.265, v_num=nk27]
# Validation DataLoader 0:   1%|▎                                    | 32/4191 [00:03<06:00, 11.52it/s]
# Epoch 0:  58%|███████████████▋           | 5733/9892 [24:21<17:40,  3.92it/s, loss=0.265, v_num=nk27]
# Epoch 0:  58%|███████████████▋           | 5734/9892 [24:21<17:40,  3.92it/s, loss=0.265, v_num=nk27]
# Validation DataLoader 0:   1%|▎                                    | 34/4191 [00:03<05:45, 12.03it/s]
# Epoch 0:  58%|███████████████▋           | 5735/9892 [24:22<17:39,  3.92it/s, loss=0.265, v_num=nk27]
# Epoch 0:  58%|███████████████▋           | 5736/9892 [24:22<17:39,  3.92it/s, loss=0.265, v_num=nk27]
# Validation DataLoader 0:   1%|▎                                    | 36/4191 [00:03<05:48, 11.93it/s]
# Epoch 0:  58%|███████████████▋           | 5737/9892 [24:22<17:39,  3.92it/s, loss=0.265, v_num=nk27]
# Epoch 0:  58%|███████████████▋           | 5738/9892 [24:22<17:38,  3.92it/s, loss=0.265, v_num=nk27]
# Validation DataLoader 0:   1%|▎                                    | 38/4191 [00:03<05:56, 11.64it/s]
# Epoch 0:  58%|███████████████▋           | 5739/9892 [24:22<17:38,  3.92it/s, loss=0.265, v_num=nk27]
# Epoch 0:  58%|███████████████▋           | 5740/9892 [24:22<17:37,  3.92it/s, loss=0.265, v_num=nk27]
# Validation DataLoader 0:   1%|▎                                    | 40/4191 [00:03<05:47, 11.95it/s]
# Epoch 0:  58%|███████████████▋           | 5741/9892 [24:22<17:37,  3.93it/s, loss=0.265, v_num=nk27]
# Epoch 0:  58%|███████████████▋           | 5742/9892 [24:22<17:37,  3.93it/s, loss=0.265, v_num=nk27]
# Validation DataLoader 0:   1%|▎                                    | 42/4191 [00:04<05:28, 12.63it/s]
# Epoch 0:  58%|███████████████▋           | 5743/9892 [24:22<17:36,  3.93it/s, loss=0.265, v_num=nk27]
# Epoch 0:  58%|███████████████▋           | 5744/9892 [24:22<17:36,  3.93it/s, loss=0.265, v_num=nk27]
# Validation DataLoader 0:   1%|▍                                    | 44/4191 [00:04<05:13, 13.21it/s]
# Epoch 0:  58%|███████████████▋           | 5745/9892 [24:22<17:35,  3.93it/s, loss=0.265, v_num=nk27]
# Epoch 0:  58%|███████████████▋           | 5746/9892 [24:22<17:35,  3.93it/s, loss=0.265, v_num=nk27]
# Validation DataLoader 0:   1%|▍                                    | 46/4191 [00:04<05:02, 13.72it/s]
# Epoch 0:  58%|███████████████▋           | 5747/9892 [24:22<17:35,  3.93it/s, loss=0.265, v_num=nk27]
# Epoch 0:  58%|███████████████▋           | 5748/9892 [24:23<17:34,  3.93it/s, loss=0.265, v_num=nk27]
# Validation DataLoader 0:   1%|▍                                    | 48/4191 [00:04<05:04, 13.59it/s]
# Epoch 0:  58%|███████████████▋           | 5749/9892 [24:23<17:34,  3.93it/s, loss=0.265, v_num=nk27]
# Epoch 0:  58%|███████████████▋           | 5750/9892 [24:23<17:34,  3.93it/s, loss=0.265, v_num=nk27]
# Validation DataLoader 0:   1%|▍                                    | 50/4191 [00:04<06:28, 10.65it/s]
# Epoch 0:  58%|███████████████▋           | 5751/9892 [24:23<17:33,  3.93it/s, loss=0.265, v_num=nk27]
# Epoch 0:  58%|███████████████▋           | 5752/9892 [24:23<17:33,  3.93it/s, loss=0.265, v_num=nk27]
# Validation DataLoader 0:   1%|▍                                    | 52/4191 [00:04<06:18, 10.94it/s]
# Epoch 0:  58%|███████████████▋           | 5753/9892 [24:23<17:32,  3.93it/s, loss=0.265, v_num=nk27]
# Epoch 0:  58%|███████████████▋           | 5754/9892 [24:23<17:32,  3.93it/s, loss=0.265, v_num=nk27]
# Validation DataLoader 0:   1%|▍                                    | 54/4191 [00:05<06:00, 11.47it/s]
# Epoch 0:  58%|███████████████▋           | 5755/9892 [24:23<17:32,  3.93it/s, loss=0.265, v_num=nk27]
# Epoch 0:  58%|███████████████▋           | 5756/9892 [24:23<17:31,  3.93it/s, loss=0.265, v_num=nk27]
# Validation DataLoader 0:   1%|▍                                    | 56/4191 [00:05<05:39, 12.17it/s]
# Epoch 0:  58%|███████████████▋           | 5757/9892 [24:23<17:31,  3.93it/s, loss=0.265, v_num=nk27]
# Epoch 0:  58%|███████████████▋           | 5758/9892 [24:23<17:31,  3.93it/s, loss=0.265, v_num=nk27]
# Validation DataLoader 0:   1%|▌                                    | 58/4191 [00:05<05:53, 11.70it/s]
# Epoch 0:  58%|███████████████▋           | 5759/9892 [24:24<17:30,  3.93it/s, loss=0.265, v_num=nk27]
# Epoch 0:  58%|███████████████▋           | 5760/9892 [24:24<17:30,  3.93it/s, loss=0.265, v_num=nk27]
# Validation DataLoader 0:   1%|▌                                    | 60/4191 [00:05<05:47, 11.88it/s]
# Epoch 0:  58%|███████████████▋           | 5761/9892 [24:24<17:29,  3.93it/s, loss=0.265, v_num=nk27]
# Epoch 0:  58%|███████████████▋           | 5762/9892 [24:24<17:29,  3.94it/s, loss=0.265, v_num=nk27]
# Validation DataLoader 0:   1%|▌                                    | 62/4191 [00:05<05:31, 12.46it/s]
# Epoch 0:  58%|███████████████▋           | 5763/9892 [24:24<17:29,  3.94it/s, loss=0.265, v_num=nk27]
# Epoch 0:  58%|███████████████▋           | 5764/9892 [24:24<17:28,  3.94it/s, loss=0.265, v_num=nk27]
# Validation DataLoader 0:   2%|▌                                    | 64/4191 [00:05<05:30, 12.49it/s]
# Epoch 0:  58%|███████████████▋           | 5765/9892 [24:24<17:28,  3.94it/s, loss=0.265, v_num=nk27]
# Epoch 0:  58%|███████████████▋           | 5766/9892 [24:24<17:28,  3.94it/s, loss=0.265, v_num=nk27]
# Validation DataLoader 0:   2%|▌                                    | 66/4191 [00:06<05:51, 11.73it/s]
# Epoch 0:  58%|███████████████▋           | 5767/9892 [24:24<17:27,  3.94it/s, loss=0.265, v_num=nk27]
# Epoch 0:  58%|███████████████▋           | 5768/9892 [24:24<17:27,  3.94it/s, loss=0.265, v_num=nk27]
# Validation DataLoader 0:   2%|▌                                    | 68/4191 [00:06<05:31, 12.43it/s]
# Epoch 0:  58%|███████████████▋           | 5769/9892 [24:24<17:26,  3.94it/s, loss=0.265, v_num=nk27]
# Epoch 0:  58%|███████████████▋           | 5770/9892 [24:24<17:26,  3.94it/s, loss=0.265, v_num=nk27]
# Validation DataLoader 0:   2%|▌                                    | 70/4191 [00:06<05:44, 11.95it/s]
# Epoch 0:  58%|███████████████▊           | 5771/9892 [24:25<17:26,  3.94it/s, loss=0.265, v_num=nk27]
# Epoch 0:  58%|███████████████▊           | 5772/9892 [24:25<17:25,  3.94it/s, loss=0.265, v_num=nk27]
# Validation DataLoader 0:   2%|▋                                    | 72/4191 [00:06<05:36, 12.24it/s]
# Epoch 0:  58%|███████████████▊           | 5773/9892 [24:25<17:25,  3.94it/s, loss=0.265, v_num=nk27]
# Epoch 0:  58%|███████████████▊           | 5774/9892 [24:25<17:25,  3.94it/s, loss=0.265, v_num=nk27]
# Validation DataLoader 0:   2%|▋                                    | 74/4191 [00:06<05:47, 11.84it/s]
# Epoch 0:  58%|███████████████▊           | 5775/9892 [24:25<17:24,  3.94it/s, loss=0.265, v_num=nk27]
# Epoch 0:  58%|███████████████▊           | 5776/9892 [24:25<17:24,  3.94it/s, loss=0.265, v_num=nk27]
# Validation DataLoader 0:   2%|▋                                    | 76/4191 [00:06<06:25, 10.67it/s]
# Epoch 0:  58%|███████████████▊           | 5777/9892 [24:25<17:23,  3.94it/s, loss=0.265, v_num=nk27]
# Epoch 0:  58%|███████████████▊           | 5778/9892 [24:25<17:23,  3.94it/s, loss=0.265, v_num=nk27]
# Validation DataLoader 0:   2%|▋                                    | 78/4191 [00:07<06:27, 10.62it/s]
# Epoch 0:  58%|███████████████▊           | 5779/9892 [24:25<17:23,  3.94it/s, loss=0.265, v_num=nk27]
# Epoch 0:  58%|███████████████▊           | 5780/9892 [24:25<17:22,  3.94it/s, loss=0.265, v_num=nk27]
# Validation DataLoader 0:   2%|▋                                    | 80/4191 [00:07<06:05, 11.23it/s]
# Epoch 0:  58%|███████████████▊           | 5781/9892 [24:25<17:22,  3.94it/s, loss=0.265, v_num=nk27]
# Epoch 0:  58%|███████████████▊           | 5782/9892 [24:26<17:22,  3.94it/s, loss=0.265, v_num=nk27]
# Validation DataLoader 0:   2%|▋                                    | 82/4191 [00:07<05:52, 11.67it/s]
# Epoch 0:  58%|███████████████▊           | 5783/9892 [24:26<17:21,  3.94it/s, loss=0.265, v_num=nk27]
# Epoch 0:  58%|███████████████▊           | 5784/9892 [24:26<17:21,  3.94it/s, loss=0.265, v_num=nk27]
# Validation DataLoader 0:   2%|▋                                    | 84/4191 [00:07<06:21, 10.78it/s]
# Epoch 0:  58%|███████████████▊           | 5785/9892 [24:26<17:20,  3.95it/s, loss=0.265, v_num=nk27]
# Epoch 0:  58%|███████████████▊           | 5786/9892 [24:26<17:20,  3.95it/s, loss=0.265, v_num=nk27]
# Validation DataLoader 0:   2%|▊                                    | 86/4191 [00:07<06:33, 10.44it/s]
# Epoch 0:  59%|███████████████▊           | 5787/9892 [24:26<17:20,  3.95it/s, loss=0.265, v_num=nk27]
# Epoch 0:  59%|███████████████▊           | 5788/9892 [24:26<17:19,  3.95it/s, loss=0.265, v_num=nk27]
# Validation DataLoader 0:   2%|▊                                    | 88/4191 [00:08<06:55,  9.87it/s]
# Epoch 0:  59%|███████████████▊           | 5789/9892 [24:26<17:19,  3.95it/s, loss=0.265, v_num=nk27]
# Epoch 0:  59%|███████████████▊           | 5790/9892 [24:26<17:19,  3.95it/s, loss=0.265, v_num=nk27]
# Validation DataLoader 0:   2%|▊                                    | 90/4191 [00:08<06:36, 10.35it/s]
# Epoch 0:  59%|███████████████▊           | 5791/9892 [24:26<17:18,  3.95it/s, loss=0.265, v_num=nk27]
# Epoch 0:  59%|███████████████▊           | 5792/9892 [24:27<17:18,  3.95it/s, loss=0.265, v_num=nk27]
# Validation DataLoader 0:   2%|▊                                    | 92/4191 [00:08<06:23, 10.69it/s]
# Epoch 0:  59%|███████████████▊           | 5793/9892 [24:27<17:18,  3.95it/s, loss=0.265, v_num=nk27]
# Epoch 0:  59%|███████████████▊           | 5794/9892 [24:27<17:17,  3.95it/s, loss=0.265, v_num=nk27]
# Validation DataLoader 0:   2%|▊                                    | 94/4191 [00:08<06:00, 11.36it/s]
# Epoch 0:  59%|███████████████▊           | 5795/9892 [24:27<17:17,  3.95it/s, loss=0.265, v_num=nk27]
# Epoch 0:  59%|███████████████▊           | 5796/9892 [24:27<17:16,  3.95it/s, loss=0.265, v_num=nk27]
# Validation DataLoader 0:   2%|▊                                    | 96/4191 [00:08<06:01, 11.32it/s]
# Epoch 0:  59%|███████████████▊           | 5797/9892 [24:27<17:16,  3.95it/s, loss=0.265, v_num=nk27]
# Epoch 0:  59%|███████████████▊           | 5798/9892 [24:27<17:16,  3.95it/s, loss=0.265, v_num=nk27]
# Validation DataLoader 0:   2%|▊                                    | 98/4191 [00:08<06:02, 11.30it/s]
# Epoch 0:  59%|███████████████▊           | 5799/9892 [24:27<17:15,  3.95it/s, loss=0.265, v_num=nk27]
# Epoch 0:  59%|███████████████▊           | 5800/9892 [24:27<17:15,  3.95it/s, loss=0.265, v_num=nk27]
# Validation DataLoader 0:   2%|▊                                   | 100/4191 [00:09<06:33, 10.39it/s]
# Epoch 0:  59%|███████████████▊           | 5801/9892 [24:27<17:15,  3.95it/s, loss=0.265, v_num=nk27]
# Epoch 0:  59%|███████████████▊           | 5802/9892 [24:27<17:14,  3.95it/s, loss=0.265, v_num=nk27]
# Validation DataLoader 0:   2%|▉                                   | 102/4191 [00:09<06:09, 11.06it/s]
# Epoch 0:  59%|███████████████▊           | 5803/9892 [24:27<17:14,  3.95it/s, loss=0.265, v_num=nk27]
# Epoch 0:  59%|███████████████▊           | 5804/9892 [24:28<17:14,  3.95it/s, loss=0.265, v_num=nk27]
# Validation DataLoader 0:   2%|▉                                   | 104/4191 [00:09<07:05,  9.59it/s]
# Epoch 0:  59%|███████████████▊           | 5805/9892 [24:28<17:13,  3.95it/s, loss=0.265, v_num=nk27]
# Epoch 0:  59%|███████████████▊           | 5806/9892 [24:28<17:13,  3.95it/s, loss=0.265, v_num=nk27]
# Validation DataLoader 0:   3%|▉                                   | 106/4191 [00:09<06:35, 10.33it/s]
# Epoch 0:  59%|███████████████▊           | 5807/9892 [24:28<17:12,  3.95it/s, loss=0.265, v_num=nk27]
# Epoch 0:  59%|███████████████▊           | 5808/9892 [24:28<17:12,  3.96it/s, loss=0.265, v_num=nk27]
# Validation DataLoader 0:   3%|▉                                   | 108/4191 [00:09<06:16, 10.83it/s]
# Epoch 0:  59%|███████████████▊           | 5809/9892 [24:28<17:12,  3.96it/s, loss=0.265, v_num=nk27]
# Epoch 0:  59%|███████████████▊           | 5810/9892 [24:28<17:11,  3.96it/s, loss=0.265, v_num=nk27]
# Validation DataLoader 0:   3%|▉                                   | 110/4191 [00:10<06:50,  9.95it/s]
# Epoch 0:  59%|███████████████▊           | 5811/9892 [24:28<17:11,  3.96it/s, loss=0.265, v_num=nk27]
# Epoch 0:  59%|███████████████▊           | 5812/9892 [24:28<17:11,  3.96it/s, loss=0.265, v_num=nk27]
# Validation DataLoader 0:   3%|▉                                   | 112/4191 [00:10<06:21, 10.70it/s]
# Epoch 0:  59%|███████████████▊           | 5813/9892 [24:28<17:10,  3.96it/s, loss=0.265, v_num=nk27]
# Epoch 0:  59%|███████████████▊           | 5814/9892 [24:29<17:10,  3.96it/s, loss=0.265, v_num=nk27]
# Validation DataLoader 0:   3%|▉                                   | 114/4191 [00:10<06:01, 11.27it/s]
# Epoch 0:  59%|███████████████▊           | 5815/9892 [24:29<17:10,  3.96it/s, loss=0.265, v_num=nk27]
# Epoch 0:  59%|███████████████▊           | 5816/9892 [24:29<17:09,  3.96it/s, loss=0.265, v_num=nk27]
# Validation DataLoader 0:   3%|▉                                   | 116/4191 [00:10<06:54,  9.83it/s]
# Epoch 0:  59%|███████████████▉           | 5817/9892 [24:29<17:09,  3.96it/s, loss=0.265, v_num=nk27]
# Epoch 0:  59%|███████████████▉           | 5818/9892 [24:29<17:08,  3.96it/s, loss=0.265, v_num=nk27]
# Validation DataLoader 0:   3%|█                                   | 118/4191 [00:10<06:23, 10.61it/s]
# Epoch 0:  59%|███████████████▉           | 5819/9892 [24:29<17:08,  3.96it/s, loss=0.265, v_num=nk27]
# Epoch 0:  59%|███████████████▉           | 5820/9892 [24:29<17:08,  3.96it/s, loss=0.265, v_num=nk27]
# Validation DataLoader 0:   3%|█                                   | 120/4191 [00:11<06:30, 10.43it/s]
# Epoch 0:  59%|███████████████▉           | 5821/9892 [24:29<17:07,  3.96it/s, loss=0.265, v_num=nk27]
# Epoch 0:  59%|███████████████▉           | 5822/9892 [24:29<17:07,  3.96it/s, loss=0.265, v_num=nk27]
# Validation DataLoader 0:   3%|█                                   | 122/4191 [00:11<06:57,  9.75it/s]
# Epoch 0:  59%|███████████████▉           | 5823/9892 [24:29<17:07,  3.96it/s, loss=0.265, v_num=nk27]
# Epoch 0:  59%|███████████████▉           | 5824/9892 [24:30<17:06,  3.96it/s, loss=0.265, v_num=nk27]
# Validation DataLoader 0:   3%|█                                   | 124/4191 [00:11<07:07,  9.51it/s]
# Epoch 0:  59%|███████████████▉           | 5825/9892 [24:30<17:06,  3.96it/s, loss=0.265, v_num=nk27]
# Epoch 0:  59%|███████████████▉           | 5826/9892 [24:30<17:06,  3.96it/s, loss=0.265, v_num=nk27]
# Validation DataLoader 0:   3%|█                                   | 126/4191 [00:11<06:38, 10.21it/s]
# Epoch 0:  59%|███████████████▉           | 5827/9892 [24:30<17:05,  3.96it/s, loss=0.265, v_num=nk27]
# Epoch 0:  59%|███████████████▉           | 5828/9892 [24:30<17:05,  3.96it/s, loss=0.265, v_num=nk27]
# Validation DataLoader 0:   3%|█                                   | 128/4191 [00:11<06:01, 11.24it/s]
# Epoch 0:  59%|███████████████▉           | 5829/9892 [24:30<17:04,  3.96it/s, loss=0.265, v_num=nk27]
# Epoch 0:  59%|███████████████▉           | 5830/9892 [24:30<17:04,  3.96it/s, loss=0.265, v_num=nk27]
# Validation DataLoader 0:   3%|█                                   | 130/4191 [00:12<06:25, 10.53it/s]
# Epoch 0:  59%|███████████████▉           | 5831/9892 [24:30<17:04,  3.96it/s, loss=0.265, v_num=nk27]
# Epoch 0:  59%|███████████████▉           | 5832/9892 [24:30<17:03,  3.97it/s, loss=0.265, v_num=nk27]
# Validation DataLoader 0:   3%|█▏                                  | 132/4191 [00:12<06:03, 11.16it/s]
# Epoch 0:  59%|███████████████▉           | 5833/9892 [24:30<17:03,  3.97it/s, loss=0.265, v_num=nk27]
# Epoch 0:  59%|███████████████▉           | 5834/9892 [24:30<17:03,  3.97it/s, loss=0.265, v_num=nk27]
# Validation DataLoader 0:   3%|█▏                                  | 134/4191 [00:12<05:46, 11.72it/s]
# Epoch 0:  59%|███████████████▉           | 5835/9892 [24:31<17:02,  3.97it/s, loss=0.265, v_num=nk27]
# Epoch 0:  59%|███████████████▉           | 5836/9892 [24:31<17:02,  3.97it/s, loss=0.265, v_num=nk27]
# Validation DataLoader 0:   3%|█▏                                  | 136/4191 [00:12<05:33, 12.15it/s]
# Epoch 0:  59%|███████████████▉           | 5837/9892 [24:31<17:02,  3.97it/s, loss=0.265, v_num=nk27]
# Epoch 0:  59%|███████████████▉           | 5838/9892 [24:31<17:01,  3.97it/s, loss=0.265, v_num=nk27]
# Validation DataLoader 0:   3%|█▏                                  | 138/4191 [00:12<05:17, 12.75it/s]
# Epoch 0:  59%|███████████████▉           | 5839/9892 [24:31<17:01,  3.97it/s, loss=0.265, v_num=nk27]
# Epoch 0:  59%|███████████████▉           | 5840/9892 [24:31<17:00,  3.97it/s, loss=0.265, v_num=nk27]
# Validation DataLoader 0:   3%|█▏                                  | 140/4191 [00:12<05:11, 13.01it/s]
# Epoch 0:  59%|███████████████▉           | 5841/9892 [24:31<17:00,  3.97it/s, loss=0.265, v_num=nk27]
# Epoch 0:  59%|███████████████▉           | 5842/9892 [24:31<17:00,  3.97it/s, loss=0.265, v_num=nk27]
# Validation DataLoader 0:   3%|█▏                                  | 142/4191 [00:12<05:16, 12.78it/s]
# Epoch 0:  59%|███████████████▉           | 5843/9892 [24:31<16:59,  3.97it/s, loss=0.265, v_num=nk27]
# Epoch 0:  59%|███████████████▉           | 5844/9892 [24:31<16:59,  3.97it/s, loss=0.265, v_num=nk27]
# Validation DataLoader 0:   3%|█▏                                  | 144/4191 [00:13<05:08, 13.12it/s]
# Epoch 0:  59%|███████████████▉           | 5845/9892 [24:31<16:59,  3.97it/s, loss=0.265, v_num=nk27]
# Epoch 0:  59%|███████████████▉           | 5846/9892 [24:31<16:58,  3.97it/s, loss=0.265, v_num=nk27]
# Validation DataLoader 0:   3%|█▎                                  | 146/4191 [00:13<05:14, 12.87it/s]
# Epoch 0:  59%|███████████████▉           | 5847/9892 [24:31<16:58,  3.97it/s, loss=0.265, v_num=nk27]
# Epoch 0:  59%|███████████████▉           | 5848/9892 [24:32<16:57,  3.97it/s, loss=0.265, v_num=nk27]
# Validation DataLoader 0:   4%|█▎                                  | 148/4191 [00:13<05:53, 11.44it/s]
# Epoch 0:  59%|███████████████▉           | 5849/9892 [24:32<16:57,  3.97it/s, loss=0.265, v_num=nk27]
# Epoch 0:  59%|███████████████▉           | 5850/9892 [24:32<16:57,  3.97it/s, loss=0.265, v_num=nk27]
# Validation DataLoader 0:   4%|█▎                                  | 150/4191 [00:13<05:40, 11.87it/s]
# Epoch 0:  59%|███████████████▉           | 5851/9892 [24:32<16:56,  3.97it/s, loss=0.265, v_num=nk27]
# Epoch 0:  59%|███████████████▉           | 5852/9892 [24:32<16:56,  3.97it/s, loss=0.265, v_num=nk27]
# Validation DataLoader 0:   4%|█▎                                  | 152/4191 [00:13<05:32, 12.16it/s]
# Epoch 0:  59%|███████████████▉           | 5853/9892 [24:32<16:56,  3.98it/s, loss=0.265, v_num=nk27]
# Epoch 0:  59%|███████████████▉           | 5854/9892 [24:32<16:55,  3.98it/s, loss=0.265, v_num=nk27]
# Validation DataLoader 0:   4%|█▎                                  | 154/4191 [00:13<05:20, 12.60it/s]
# Epoch 0:  59%|███████████████▉           | 5855/9892 [24:32<16:55,  3.98it/s, loss=0.265, v_num=nk27]
# Epoch 0:  59%|███████████████▉           | 5856/9892 [24:32<16:54,  3.98it/s, loss=0.265, v_num=nk27]
# Validation DataLoader 0:   4%|█▎                                  | 156/4191 [00:14<05:12, 12.92it/s]
# Epoch 0:  59%|███████████████▉           | 5857/9892 [24:32<16:54,  3.98it/s, loss=0.265, v_num=nk27]
# Epoch 0:  59%|███████████████▉           | 5858/9892 [24:32<16:54,  3.98it/s, loss=0.265, v_num=nk27]
# Validation DataLoader 0:   4%|█▎                                  | 158/4191 [00:14<04:58, 13.50it/s]
# Epoch 0:  59%|███████████████▉           | 5859/9892 [24:32<16:53,  3.98it/s, loss=0.265, v_num=nk27]
# Epoch 0:  59%|███████████████▉           | 5860/9892 [24:32<16:53,  3.98it/s, loss=0.265, v_num=nk27]
# Validation DataLoader 0:   4%|█▎                                  | 160/4191 [00:14<05:04, 13.23it/s]
# Epoch 0:  59%|███████████████▉           | 5861/9892 [24:33<16:53,  3.98it/s, loss=0.265, v_num=nk27]
# Epoch 0:  59%|████████████████           | 5862/9892 [24:33<16:52,  3.98it/s, loss=0.265, v_num=nk27]
# Validation DataLoader 0:   4%|█▍                                  | 162/4191 [00:14<05:05, 13.17it/s]
# Epoch 0:  59%|████████████████           | 5863/9892 [24:33<16:52,  3.98it/s, loss=0.265, v_num=nk27]
# Epoch 0:  59%|████████████████           | 5864/9892 [24:33<16:51,  3.98it/s, loss=0.265, v_num=nk27]
# Validation DataLoader 0:   4%|█▍                                  | 164/4191 [00:14<04:56, 13.58it/s]
# Epoch 0:  59%|████████████████           | 5865/9892 [24:33<16:51,  3.98it/s, loss=0.265, v_num=nk27]
# Epoch 0:  59%|████████████████           | 5866/9892 [24:33<16:51,  3.98it/s, loss=0.265, v_num=nk27]
# Validation DataLoader 0:   4%|█▍                                  | 166/4191 [00:14<05:18, 12.65it/s]
# Epoch 0:  59%|████████████████           | 5867/9892 [24:33<16:50,  3.98it/s, loss=0.265, v_num=nk27]
# Epoch 0:  59%|████████████████           | 5868/9892 [24:33<16:50,  3.98it/s, loss=0.265, v_num=nk27]
# Validation DataLoader 0:   4%|█▍                                  | 168/4191 [00:15<05:28, 12.23it/s]
# Epoch 0:  59%|████████████████           | 5869/9892 [24:33<16:50,  3.98it/s, loss=0.265, v_num=nk27]
# Epoch 0:  59%|████████████████           | 5870/9892 [24:33<16:49,  3.98it/s, loss=0.265, v_num=nk27]
# Validation DataLoader 0:   4%|█▍                                  | 170/4191 [00:15<05:23, 12.44it/s]
# Epoch 0:  59%|████████████████           | 5871/9892 [24:33<16:49,  3.98it/s, loss=0.265, v_num=nk27]
# Epoch 0:  59%|████████████████           | 5872/9892 [24:33<16:49,  3.98it/s, loss=0.265, v_num=nk27]
# Validation DataLoader 0:   4%|█▍                                  | 172/4191 [00:15<05:30, 12.17it/s]
# Epoch 0:  59%|████████████████           | 5873/9892 [24:34<16:48,  3.98it/s, loss=0.265, v_num=nk27]
# Epoch 0:  59%|████████████████           | 5874/9892 [24:34<16:48,  3.98it/s, loss=0.265, v_num=nk27]
# Validation DataLoader 0:   4%|█▍                                  | 174/4191 [00:15<05:23, 12.41it/s]
# Epoch 0:  59%|████████████████           | 5875/9892 [24:34<16:47,  3.99it/s, loss=0.265, v_num=nk27]
# Epoch 0:  59%|████████████████           | 5876/9892 [24:34<16:47,  3.99it/s, loss=0.265, v_num=nk27]
# Validation DataLoader 0:   4%|█▌                                  | 176/4191 [00:15<05:43, 11.69it/s]
# Epoch 0:  59%|████████████████           | 5877/9892 [24:34<16:47,  3.99it/s, loss=0.265, v_num=nk27]
# Epoch 0:  59%|████████████████           | 5878/9892 [24:34<16:46,  3.99it/s, loss=0.265, v_num=nk27]
# Validation DataLoader 0:   4%|█▌                                  | 178/4191 [00:15<05:22, 12.43it/s]
# Epoch 0:  59%|████████████████           | 5879/9892 [24:34<16:46,  3.99it/s, loss=0.265, v_num=nk27]
# Epoch 0:  59%|████████████████           | 5880/9892 [24:34<16:46,  3.99it/s, loss=0.265, v_num=nk27]
# Validation DataLoader 0:   4%|█▌                                  | 180/4191 [00:16<05:07, 13.02it/s]
# Epoch 0:  59%|████████████████           | 5881/9892 [24:34<16:45,  3.99it/s, loss=0.265, v_num=nk27]
# Epoch 0:  59%|████████████████           | 5882/9892 [24:34<16:45,  3.99it/s, loss=0.265, v_num=nk27]
# Validation DataLoader 0:   4%|█▌                                  | 182/4191 [00:16<05:17, 12.62it/s]
# Epoch 0:  59%|████████████████           | 5883/9892 [24:34<16:45,  3.99it/s, loss=0.265, v_num=nk27]
# Epoch 0:  59%|████████████████           | 5884/9892 [24:34<16:44,  3.99it/s, loss=0.265, v_num=nk27]
# Validation DataLoader 0:   4%|█▌                                  | 184/4191 [00:16<05:12, 12.83it/s]
# Epoch 0:  59%|████████████████           | 5885/9892 [24:34<16:44,  3.99it/s, loss=0.265, v_num=nk27]
# Epoch 0:  60%|████████████████           | 5886/9892 [24:35<16:43,  3.99it/s, loss=0.265, v_num=nk27]
# Validation DataLoader 0:   4%|█▌                                  | 186/4191 [00:16<05:09, 12.93it/s]
# Epoch 0:  60%|████████████████           | 5887/9892 [24:35<16:43,  3.99it/s, loss=0.265, v_num=nk27]
# Epoch 0:  60%|████████████████           | 5888/9892 [24:35<16:43,  3.99it/s, loss=0.265, v_num=nk27]
# Validation DataLoader 0:   4%|█▌                                  | 188/4191 [00:16<04:59, 13.39it/s]
# Epoch 0:  60%|████████████████           | 5889/9892 [24:35<16:42,  3.99it/s, loss=0.265, v_num=nk27]
# Epoch 0:  60%|████████████████           | 5890/9892 [24:35<16:42,  3.99it/s, loss=0.265, v_num=nk27]
# Validation DataLoader 0:   5%|█▋                                  | 190/4191 [00:16<06:30, 10.24it/s]
# Epoch 0:  60%|████████████████           | 5891/9892 [24:35<16:42,  3.99it/s, loss=0.265, v_num=nk27]
# Epoch 0:  60%|████████████████           | 5892/9892 [24:35<16:41,  3.99it/s, loss=0.265, v_num=nk27]
# Validation DataLoader 0:   5%|█▋                                  | 192/4191 [00:17<06:20, 10.50it/s]
# Epoch 0:  60%|████████████████           | 5893/9892 [24:35<16:41,  3.99it/s, loss=0.265, v_num=nk27]
# Epoch 0:  60%|████████████████           | 5894/9892 [24:35<16:41,  3.99it/s, loss=0.265, v_num=nk27]
# Validation DataLoader 0:   5%|█▋                                  | 194/4191 [00:17<06:08, 10.83it/s]
# Epoch 0:  60%|████████████████           | 5895/9892 [24:35<16:40,  3.99it/s, loss=0.265, v_num=nk27]
# Epoch 0:  60%|████████████████           | 5896/9892 [24:35<16:40,  3.99it/s, loss=0.265, v_num=nk27]
# Validation DataLoader 0:   5%|█▋                                  | 196/4191 [00:17<05:48, 11.46it/s]
# Epoch 0:  60%|████████████████           | 5897/9892 [24:36<16:39,  4.00it/s, loss=0.265, v_num=nk27]
# Epoch 0:  60%|████████████████           | 5898/9892 [24:36<16:39,  4.00it/s, loss=0.265, v_num=nk27]
# Validation DataLoader 0:   5%|█▋                                  | 198/4191 [00:17<05:44, 11.59it/s]
# Epoch 0:  60%|████████████████           | 5899/9892 [24:36<16:39,  4.00it/s, loss=0.265, v_num=nk27]
# Epoch 0:  60%|████████████████           | 5900/9892 [24:36<16:38,  4.00it/s, loss=0.265, v_num=nk27]
# Validation DataLoader 0:   5%|█▋                                  | 200/4191 [00:17<05:26, 12.21it/s]
# Epoch 0:  60%|████████████████           | 5901/9892 [24:36<16:38,  4.00it/s, loss=0.265, v_num=nk27]
# Epoch 0:  60%|████████████████           | 5902/9892 [24:36<16:38,  4.00it/s, loss=0.265, v_num=nk27]
# Validation DataLoader 0:   5%|█▋                                  | 202/4191 [00:17<05:36, 11.85it/s]
# Epoch 0:  60%|████████████████           | 5903/9892 [24:36<16:37,  4.00it/s, loss=0.265, v_num=nk27]
# Epoch 0:  60%|████████████████           | 5904/9892 [24:36<16:37,  4.00it/s, loss=0.265, v_num=nk27]
# Validation DataLoader 0:   5%|█▊                                  | 204/4191 [00:18<05:20, 12.44it/s]
# Epoch 0:  60%|████████████████           | 5905/9892 [24:36<16:37,  4.00it/s, loss=0.265, v_num=nk27]
# Epoch 0:  60%|████████████████           | 5906/9892 [24:36<16:36,  4.00it/s, loss=0.265, v_num=nk27]
# Validation DataLoader 0:   5%|█▊                                  | 206/4191 [00:18<05:20, 12.42it/s]
# Epoch 0:  60%|████████████████           | 5907/9892 [24:36<16:36,  4.00it/s, loss=0.265, v_num=nk27]
# Epoch 0:  60%|████████████████▏          | 5908/9892 [24:36<16:35,  4.00it/s, loss=0.265, v_num=nk27]
# Validation DataLoader 0:   5%|█▊                                  | 208/4191 [00:18<05:15, 12.64it/s]
# Epoch 0:  60%|████████████████▏          | 5909/9892 [24:36<16:35,  4.00it/s, loss=0.265, v_num=nk27]
# Epoch 0:  60%|████████████████▏          | 5910/9892 [24:37<16:35,  4.00it/s, loss=0.265, v_num=nk27]
# Validation DataLoader 0:   5%|█▊                                  | 210/4191 [00:18<05:05, 13.03it/s]
# Epoch 0:  60%|████████████████▏          | 5911/9892 [24:37<16:34,  4.00it/s, loss=0.265, v_num=nk27]
# Epoch 0:  60%|████████████████▏          | 5912/9892 [24:37<16:34,  4.00it/s, loss=0.265, v_num=nk27]
# Validation DataLoader 0:   5%|█▊                                  | 212/4191 [00:18<05:04, 13.06it/s]
# Epoch 0:  60%|████████████████▏          | 5913/9892 [24:37<16:34,  4.00it/s, loss=0.265, v_num=nk27]
# Epoch 0:  60%|████████████████▏          | 5914/9892 [24:37<16:33,  4.00it/s, loss=0.265, v_num=nk27]
# Validation DataLoader 0:   5%|█▊                                  | 214/4191 [00:18<05:19, 12.45it/s]
# Epoch 0:  60%|████████████████▏          | 5915/9892 [24:37<16:33,  4.00it/s, loss=0.265, v_num=nk27]
# Epoch 0:  60%|████████████████▏          | 5916/9892 [24:37<16:33,  4.00it/s, loss=0.265, v_num=nk27]
# Validation DataLoader 0:   5%|█▊                                  | 216/4191 [00:18<05:10, 12.81it/s]
# Epoch 0:  60%|████████████████▏          | 5917/9892 [24:37<16:32,  4.00it/s, loss=0.265, v_num=nk27]
# Epoch 0:  60%|████████████████▏          | 5918/9892 [24:37<16:32,  4.00it/s, loss=0.265, v_num=nk27]
# Validation DataLoader 0:   5%|█▊                                  | 218/4191 [00:19<05:23, 12.28it/s]
# Epoch 0:  60%|████████████████▏          | 5919/9892 [24:37<16:31,  4.01it/s, loss=0.265, v_num=nk27]
# Epoch 0:  60%|████████████████▏          | 5920/9892 [24:37<16:31,  4.01it/s, loss=0.265, v_num=nk27]
# Validation DataLoader 0:   5%|█▉                                  | 220/4191 [00:19<05:15, 12.57it/s]
# Epoch 0:  60%|████████████████▏          | 5921/9892 [24:37<16:31,  4.01it/s, loss=0.265, v_num=nk27]
# Epoch 0:  60%|████████████████▏          | 5922/9892 [24:38<16:30,  4.01it/s, loss=0.265, v_num=nk27]
# Validation DataLoader 0:   5%|█▉                                  | 222/4191 [00:19<05:07, 12.89it/s]
# Epoch 0:  60%|████████████████▏          | 5923/9892 [24:38<16:30,  4.01it/s, loss=0.265, v_num=nk27]
# Epoch 0:  60%|████████████████▏          | 5924/9892 [24:38<16:30,  4.01it/s, loss=0.265, v_num=nk27]
# Validation DataLoader 0:   5%|█▉                                  | 224/4191 [00:19<05:10, 12.80it/s]
# Epoch 0:  60%|████████████████▏          | 5925/9892 [24:38<16:29,  4.01it/s, loss=0.265, v_num=nk27]
# Epoch 0:  60%|████████████████▏          | 5926/9892 [24:38<16:29,  4.01it/s, loss=0.265, v_num=nk27]
# Validation DataLoader 0:   5%|█▉                                  | 226/4191 [00:19<05:03, 13.07it/s]
# Epoch 0:  60%|████████████████▏          | 5927/9892 [24:38<16:29,  4.01it/s, loss=0.265, v_num=nk27]
# Epoch 0:  60%|████████████████▏          | 5928/9892 [24:38<16:28,  4.01it/s, loss=0.265, v_num=nk27]
# Validation DataLoader 0:   5%|█▉                                  | 228/4191 [00:19<04:59, 13.24it/s]
# Epoch 0:  60%|████████████████▏          | 5929/9892 [24:38<16:28,  4.01it/s, loss=0.265, v_num=nk27]
# Epoch 0:  60%|████████████████▏          | 5930/9892 [24:38<16:27,  4.01it/s, loss=0.265, v_num=nk27]
# Validation DataLoader 0:   5%|█▉                                  | 230/4191 [00:20<04:47, 13.78it/s]
# Epoch 0:  60%|████████████████▏          | 5931/9892 [24:38<16:27,  4.01it/s, loss=0.265, v_num=nk27]
# Epoch 0:  60%|████████████████▏          | 5932/9892 [24:38<16:27,  4.01it/s, loss=0.265, v_num=nk27]
# Validation DataLoader 0:   6%|█▉                                  | 232/4191 [00:20<05:14, 12.60it/s]
# Epoch 0:  60%|████████████████▏          | 5933/9892 [24:38<16:26,  4.01it/s, loss=0.265, v_num=nk27]
# Epoch 0:  60%|████████████████▏          | 5934/9892 [24:38<16:26,  4.01it/s, loss=0.265, v_num=nk27]
# Validation DataLoader 0:   6%|██                                  | 234/4191 [00:20<05:10, 12.74it/s]
# Epoch 0:  60%|████████████████▏          | 5935/9892 [24:39<16:26,  4.01it/s, loss=0.265, v_num=nk27]
# Epoch 0:  60%|████████████████▏          | 5936/9892 [24:39<16:25,  4.01it/s, loss=0.265, v_num=nk27]
# Validation DataLoader 0:   6%|██                                  | 236/4191 [00:20<05:27, 12.08it/s]
# Epoch 0:  60%|████████████████▏          | 5937/9892 [24:39<16:25,  4.01it/s, loss=0.265, v_num=nk27]
# Epoch 0:  60%|████████████████▏          | 5938/9892 [24:39<16:25,  4.01it/s, loss=0.265, v_num=nk27]
# Validation DataLoader 0:   6%|██                                  | 238/4191 [00:20<05:21, 12.31it/s]
# Epoch 0:  60%|████████████████▏          | 5939/9892 [24:39<16:24,  4.01it/s, loss=0.265, v_num=nk27]
# Epoch 0:  60%|████████████████▏          | 5940/9892 [24:39<16:24,  4.02it/s, loss=0.265, v_num=nk27]
# Validation DataLoader 0:   6%|██                                  | 240/4191 [00:20<05:06, 12.91it/s]
# Epoch 0:  60%|████████████████▏          | 5941/9892 [24:39<16:23,  4.02it/s, loss=0.265, v_num=nk27]
# Epoch 0:  60%|████████████████▏          | 5942/9892 [24:39<16:23,  4.02it/s, loss=0.265, v_num=nk27]
# Validation DataLoader 0:   6%|██                                  | 242/4191 [00:20<04:51, 13.55it/s]
# Epoch 0:  60%|████████████████▏          | 5943/9892 [24:39<16:23,  4.02it/s, loss=0.265, v_num=nk27]
# Epoch 0:  60%|████████████████▏          | 5944/9892 [24:39<16:22,  4.02it/s, loss=0.265, v_num=nk27]
# Validation DataLoader 0:   6%|██                                  | 244/4191 [00:21<04:58, 13.21it/s]
# Epoch 0:  60%|████████████████▏          | 5945/9892 [24:39<16:22,  4.02it/s, loss=0.265, v_num=nk27]
# Epoch 0:  60%|████████████████▏          | 5946/9892 [24:39<16:22,  4.02it/s, loss=0.265, v_num=nk27]
# Validation DataLoader 0:   6%|██                                  | 246/4191 [00:21<04:49, 13.62it/s]
# Epoch 0:  60%|████████████████▏          | 5947/9892 [24:39<16:21,  4.02it/s, loss=0.265, v_num=nk27]
# Epoch 0:  60%|████████████████▏          | 5948/9892 [24:39<16:21,  4.02it/s, loss=0.265, v_num=nk27]
# Validation DataLoader 0:   6%|██▏                                 | 248/4191 [00:21<04:43, 13.89it/s]
# Epoch 0:  60%|████████████████▏          | 5949/9892 [24:40<16:20,  4.02it/s, loss=0.265, v_num=nk27]
# Epoch 0:  60%|████████████████▏          | 5950/9892 [24:40<16:20,  4.02it/s, loss=0.265, v_num=nk27]
# Validation DataLoader 0:   6%|██▏                                 | 250/4191 [00:21<05:17, 12.42it/s]
# Epoch 0:  60%|████████████████▏          | 5951/9892 [24:40<16:20,  4.02it/s, loss=0.265, v_num=nk27]
# Epoch 0:  60%|████████████████▏          | 5952/9892 [24:40<16:19,  4.02it/s, loss=0.265, v_num=nk27]
# Validation DataLoader 0:   6%|██▏                                 | 252/4191 [00:21<05:55, 11.09it/s]
# Epoch 0:  60%|████████████████▏          | 5953/9892 [24:40<16:19,  4.02it/s, loss=0.265, v_num=nk27]
# Epoch 0:  60%|████████████████▎          | 5954/9892 [24:40<16:19,  4.02it/s, loss=0.265, v_num=nk27]
# Validation DataLoader 0:   6%|██▏                                 | 254/4191 [00:21<05:32, 11.85it/s]
# Epoch 0:  60%|████████████████▎          | 5955/9892 [24:40<16:18,  4.02it/s, loss=0.265, v_num=nk27]
# Epoch 0:  60%|████████████████▎          | 5956/9892 [24:40<16:18,  4.02it/s, loss=0.265, v_num=nk27]
# Validation DataLoader 0:   6%|██▏                                 | 256/4191 [00:22<05:53, 11.12it/s]
# Epoch 0:  60%|████████████████▎          | 5957/9892 [24:40<16:18,  4.02it/s, loss=0.265, v_num=nk27]
# Epoch 0:  60%|████████████████▎          | 5958/9892 [24:40<16:17,  4.02it/s, loss=0.265, v_num=nk27]
# Validation DataLoader 0:   6%|██▏                                 | 258/4191 [00:22<05:40, 11.54it/s]
# Epoch 0:  60%|████████████████▎          | 5959/9892 [24:40<16:17,  4.02it/s, loss=0.265, v_num=nk27]
# Epoch 0:  60%|████████████████▎          | 5960/9892 [24:41<16:17,  4.02it/s, loss=0.265, v_num=nk27]
# Validation DataLoader 0:   6%|██▏                                 | 260/4191 [00:22<05:23, 12.14it/s]
# Epoch 0:  60%|████████████████▎          | 5961/9892 [24:41<16:16,  4.02it/s, loss=0.265, v_num=nk27]
# Epoch 0:  60%|████████████████▎          | 5962/9892 [24:41<16:16,  4.03it/s, loss=0.265, v_num=nk27]
# Validation DataLoader 0:   6%|██▎                                 | 262/4191 [00:22<05:25, 12.05it/s]
# Epoch 0:  60%|████████████████▎          | 5963/9892 [24:41<16:16,  4.03it/s, loss=0.265, v_num=nk27]
# Epoch 0:  60%|████████████████▎          | 5964/9892 [24:41<16:15,  4.03it/s, loss=0.265, v_num=nk27]
# Validation DataLoader 0:   6%|██▎                                 | 264/4191 [00:22<05:24, 12.08it/s]
# Epoch 0:  60%|████████████████▎          | 5965/9892 [24:41<16:15,  4.03it/s, loss=0.265, v_num=nk27]
# Epoch 0:  60%|████████████████▎          | 5966/9892 [24:41<16:14,  4.03it/s, loss=0.265, v_num=nk27]
# Validation DataLoader 0:   6%|██▎                                 | 266/4191 [00:23<05:30, 11.88it/s]
# Epoch 0:  60%|████████████████▎          | 5967/9892 [24:41<16:14,  4.03it/s, loss=0.265, v_num=nk27]
# Epoch 0:  60%|████████████████▎          | 5968/9892 [24:41<16:14,  4.03it/s, loss=0.265, v_num=nk27]
# Validation DataLoader 0:   6%|██▎                                 | 268/4191 [00:23<05:15, 12.44it/s]
# Epoch 0:  60%|████████████████▎          | 5969/9892 [24:41<16:13,  4.03it/s, loss=0.265, v_num=nk27]
# Epoch 0:  60%|████████████████▎          | 5970/9892 [24:41<16:13,  4.03it/s, loss=0.265, v_num=nk27]
# Validation DataLoader 0:   6%|██▎                                 | 270/4191 [00:23<05:22, 12.16it/s]
# Epoch 0:  60%|████████████████▎          | 5971/9892 [24:41<16:13,  4.03it/s, loss=0.265, v_num=nk27]
# Epoch 0:  60%|████████████████▎          | 5972/9892 [24:42<16:12,  4.03it/s, loss=0.265, v_num=nk27]
# Validation DataLoader 0:   6%|██▎                                 | 272/4191 [00:23<05:37, 11.60it/s]
# Epoch 0:  60%|████████████████▎          | 5973/9892 [24:42<16:12,  4.03it/s, loss=0.265, v_num=nk27]
# Epoch 0:  60%|████████████████▎          | 5974/9892 [24:42<16:12,  4.03it/s, loss=0.265, v_num=nk27]
# Validation DataLoader 0:   7%|██▎                                 | 274/4191 [00:23<05:23, 12.11it/s]
# Epoch 0:  60%|████████████████▎          | 5975/9892 [24:42<16:11,  4.03it/s, loss=0.265, v_num=nk27]
# Epoch 0:  60%|████████████████▎          | 5976/9892 [24:42<16:11,  4.03it/s, loss=0.265, v_num=nk27]
# Validation DataLoader 0:   7%|██▎                                 | 276/4191 [00:23<05:38, 11.58it/s]
# Epoch 0:  60%|████████████████▎          | 5977/9892 [24:42<16:11,  4.03it/s, loss=0.265, v_num=nk27]
# Epoch 0:  60%|████████████████▎          | 5978/9892 [24:42<16:10,  4.03it/s, loss=0.265, v_num=nk27]
# Validation DataLoader 0:   7%|██▍                                 | 278/4191 [00:24<05:32, 11.77it/s]
# Epoch 0:  60%|████████████████▎          | 5979/9892 [24:42<16:10,  4.03it/s, loss=0.265, v_num=nk27]
# Epoch 0:  60%|████████████████▎          | 5980/9892 [24:42<16:09,  4.03it/s, loss=0.265, v_num=nk27]
# Validation DataLoader 0:   7%|██▍                                 | 280/4191 [00:24<05:23, 12.09it/s]
# Epoch 0:  60%|████████████████▎          | 5981/9892 [24:42<16:09,  4.03it/s, loss=0.265, v_num=nk27]
# Epoch 0:  60%|████████████████▎          | 5982/9892 [24:42<16:09,  4.03it/s, loss=0.265, v_num=nk27]
# Validation DataLoader 0:   7%|██▍                                 | 282/4191 [00:24<05:23, 12.09it/s]
# Epoch 0:  60%|████████████████▎          | 5983/9892 [24:42<16:08,  4.03it/s, loss=0.265, v_num=nk27]
# Epoch 0:  60%|████████████████▎          | 5984/9892 [24:43<16:08,  4.03it/s, loss=0.265, v_num=nk27]
# Validation DataLoader 0:   7%|██▍                                 | 284/4191 [00:24<05:21, 12.17it/s]
# Epoch 0:  61%|████████████████▎          | 5985/9892 [24:43<16:08,  4.04it/s, loss=0.265, v_num=nk27]
# Epoch 0:  61%|████████████████▎          | 5986/9892 [24:43<16:07,  4.04it/s, loss=0.265, v_num=nk27]
# Validation DataLoader 0:   7%|██▍                                 | 286/4191 [00:24<05:07, 12.68it/s]
# Epoch 0:  61%|████████████████▎          | 5987/9892 [24:43<16:07,  4.04it/s, loss=0.265, v_num=nk27]
# Epoch 0:  61%|████████████████▎          | 5988/9892 [24:43<16:07,  4.04it/s, loss=0.265, v_num=nk27]
# Validation DataLoader 0:   7%|██▍                                 | 288/4191 [00:24<05:16, 12.34it/s]
# Epoch 0:  61%|████████████████▎          | 5989/9892 [24:43<16:06,  4.04it/s, loss=0.265, v_num=nk27]
# Epoch 0:  61%|████████████████▎          | 5990/9892 [24:43<16:06,  4.04it/s, loss=0.265, v_num=nk27]
# Validation DataLoader 0:   7%|██▍                                 | 290/4191 [00:24<05:10, 12.54it/s]
# Epoch 0:  61%|████████████████▎          | 5991/9892 [24:43<16:06,  4.04it/s, loss=0.265, v_num=nk27]
# Epoch 0:  61%|████████████████▎          | 5992/9892 [24:43<16:05,  4.04it/s, loss=0.265, v_num=nk27]
# Validation DataLoader 0:   7%|██▌                                 | 292/4191 [00:25<05:59, 10.85it/s]
# Epoch 0:  61%|████████████████▎          | 5993/9892 [24:43<16:05,  4.04it/s, loss=0.265, v_num=nk27]
# Epoch 0:  61%|████████████████▎          | 5994/9892 [24:43<16:05,  4.04it/s, loss=0.265, v_num=nk27]
# Validation DataLoader 0:   7%|██▌                                 | 294/4191 [00:25<05:49, 11.16it/s]
# Epoch 0:  61%|████████████████▎          | 5995/9892 [24:44<16:04,  4.04it/s, loss=0.265, v_num=nk27]
# Epoch 0:  61%|████████████████▎          | 5996/9892 [24:44<16:04,  4.04it/s, loss=0.265, v_num=nk27]
# Validation DataLoader 0:   7%|██▌                                 | 296/4191 [00:25<05:28, 11.85it/s]
# Epoch 0:  61%|████████████████▎          | 5997/9892 [24:44<16:03,  4.04it/s, loss=0.265, v_num=nk27]
# Epoch 0:  61%|████████████████▎          | 5998/9892 [24:44<16:03,  4.04it/s, loss=0.265, v_num=nk27]
# Validation DataLoader 0:   7%|██▌                                 | 298/4191 [00:25<05:16, 12.29it/s]
# Epoch 0:  61%|████████████████▎          | 5999/9892 [24:44<16:03,  4.04it/s, loss=0.265, v_num=nk27]
# ...
# Epoch 0:  77%|████████████████████▊      | 7642/9892 [27:01<07:57,  4.71it/s, loss=0.265, v_num=nk27]
# Validation DataLoader 0:  46%|████████████████▏                  | 1942/4191 [02:43<03:09, 11.89it/s]
# Epoch 0:  77%|████████████████████▊      | 7643/9892 [27:02<07:57,  4.71it/s, loss=0.265, v_num=nk27]
# Epoch 0:  77%|████████████████████▊      | 7644/9892 [27:02<07:57,  4.71it/s, loss=0.265, v_num=nk27]
# Validation DataLoader 0:  46%|████████████████▏                  | 1944/4191 [02:43<03:07, 11.97it/s]
# Epoch 0:  77%|████████████████████▊      | 7645/9892 [27:02<07:56,  4.71it/s, loss=0.265, v_num=nk27]
# Epoch 0:  77%|████████████████████▊      | 7646/9892 [27:02<07:56,  4.71it/s, loss=0.265, v_num=nk27]
# Validation DataLoader 0:  46%|████████████████▎                  | 1946/4191 [02:43<02:58, 12.61it/s]
# Epoch 0:  77%|████████████████████▊      | 7647/9892 [27:02<07:56,  4.71it/s, loss=0.265, v_num=nk27]
# Epoch 0:  77%|████████████████████▉      | 7648/9892 [27:02<07:56,  4.71it/s, loss=0.265, v_num=nk27]
# Validation DataLoader 0:  46%|████████████████▎                  | 1948/4191 [02:43<03:27, 10.79it/s]
# Epoch 0:  77%|████████████████████▉      | 7649/9892 [27:02<07:55,  4.71it/s, loss=0.265, v_num=nk27]
# Epoch 0:  77%|████████████████████▉      | 7650/9892 [27:02<07:55,  4.71it/s, loss=0.265, v_num=nk27]
# Validation DataLoader 0:  47%|████████████████▎                  | 1950/4191 [02:44<03:18, 11.29it/s]
# Epoch 0:  77%|████████████████████▉      | 7651/9892 [27:02<07:55,  4.71it/s, loss=0.265, v_num=nk27]
# Epoch 0:  77%|████████████████████▉      | 7652/9892 [27:02<07:55,  4.72it/s, loss=0.265, v_num=nk27]
# Validation DataLoader 0:  47%|████████████████▎                  | 1952/4191 [02:44<03:18, 11.25it/s]
# Epoch 0:  77%|████████████████████▉      | 7653/9892 [27:02<07:54,  4.72it/s, loss=0.265, v_num=nk27]
# Epoch 0:  77%|████████████████████▉      | 7654/9892 [27:03<07:54,  4.72it/s, loss=0.265, v_num=nk27]
# Validation DataLoader 0:  47%|████████████████▎                  | 1954/4191 [02:44<03:20, 11.16it/s]
# Epoch 0:  77%|████████████████████▉      | 7655/9892 [27:03<07:54,  4.72it/s, loss=0.265, v_num=nk27]
# Epoch 0:  77%|████████████████████▉      | 7656/9892 [27:03<07:54,  4.72it/s, loss=0.265, v_num=nk27]
# Validation DataLoader 0:  47%|████████████████▎                  | 1956/4191 [02:44<03:11, 11.65it/s]
# Epoch 0:  77%|████████████████████▉      | 7657/9892 [27:03<07:53,  4.72it/s, loss=0.265, v_num=nk27]
# Epoch 0:  77%|████████████████████▉      | 7658/9892 [27:03<07:53,  4.72it/s, loss=0.265, v_num=nk27]
# Validation DataLoader 0:  47%|████████████████▎                  | 1958/4191 [02:44<03:02, 12.26it/s]
# Epoch 0:  77%|████████████████████▉      | 7659/9892 [27:03<07:53,  4.72it/s, loss=0.265, v_num=nk27]
# Epoch 0:  77%|████████████████████▉      | 7660/9892 [27:03<07:53,  4.72it/s, loss=0.265, v_num=nk27]
# Validation DataLoader 0:  47%|████████████████▎                  | 1960/4191 [02:44<02:58, 12.47it/s]
# Epoch 0:  77%|████████████████████▉      | 7661/9892 [27:03<07:52,  4.72it/s, loss=0.265, v_num=nk27]
# Epoch 0:  77%|████████████████████▉      | 7662/9892 [27:03<07:52,  4.72it/s, loss=0.265, v_num=nk27]
# Validation DataLoader 0:  47%|████████████████▍                  | 1962/4191 [02:45<02:55, 12.70it/s]
# Epoch 0:  77%|████████████████████▉      | 7663/9892 [27:03<07:52,  4.72it/s, loss=0.265, v_num=nk27]
# Epoch 0:  77%|████████████████████▉      | 7664/9892 [27:03<07:52,  4.72it/s, loss=0.265, v_num=nk27]
# Validation DataLoader 0:  47%|████████████████▍                  | 1964/4191 [02:45<02:53, 12.82it/s]
# Epoch 0:  77%|████████████████████▉      | 7665/9892 [27:03<07:51,  4.72it/s, loss=0.265, v_num=nk27]
# Epoch 0:  77%|████████████████████▉      | 7666/9892 [27:03<07:51,  4.72it/s, loss=0.265, v_num=nk27]
# Validation DataLoader 0:  47%|████████████████▍                  | 1966/4191 [02:45<03:04, 12.04it/s]
# Epoch 0:  78%|████████████████████▉      | 7667/9892 [27:04<07:51,  4.72it/s, loss=0.265, v_num=nk27]
# Epoch 0:  78%|████████████████████▉      | 7668/9892 [27:04<07:51,  4.72it/s, loss=0.265, v_num=nk27]
# Validation DataLoader 0:  47%|████████████████▍                  | 1968/4191 [02:45<03:06, 11.92it/s]
# Epoch 0:  78%|████████████████████▉      | 7669/9892 [27:04<07:50,  4.72it/s, loss=0.265, v_num=nk27]
# Epoch 0:  78%|████████████████████▉      | 7670/9892 [27:04<07:50,  4.72it/s, loss=0.265, v_num=nk27]
# Validation DataLoader 0:  47%|████████████████▍                  | 1970/4191 [02:45<03:00, 12.32it/s]
# Epoch 0:  78%|████████████████████▉      | 7671/9892 [27:04<07:50,  4.72it/s, loss=0.265, v_num=nk27]
# Epoch 0:  78%|████████████████████▉      | 7672/9892 [27:04<07:50,  4.72it/s, loss=0.265, v_num=nk27]
# Validation DataLoader 0:  47%|████████████████▍                  | 1972/4191 [02:45<03:03, 12.09it/s]
# Epoch 0:  78%|████████████████████▉      | 7673/9892 [27:04<07:49,  4.72it/s, loss=0.265, v_num=nk27]
# Epoch 0:  78%|████████████████████▉      | 7674/9892 [27:04<07:49,  4.72it/s, loss=0.265, v_num=nk27]
# Validation DataLoader 0:  47%|████████████████▍                  | 1974/4191 [02:46<03:10, 11.63it/s]
# Epoch 0:  78%|████████████████████▉      | 7675/9892 [27:04<07:49,  4.72it/s, loss=0.265, v_num=nk27]
# Epoch 0:  78%|████████████████████▉      | 7676/9892 [27:04<07:49,  4.72it/s, loss=0.265, v_num=nk27]
# Validation DataLoader 0:  47%|████████████████▌                  | 1976/4191 [02:46<03:02, 12.11it/s]
# Epoch 0:  78%|████████████████████▉      | 7677/9892 [27:04<07:48,  4.72it/s, loss=0.265, v_num=nk27]
# Epoch 0:  78%|████████████████████▉      | 7678/9892 [27:04<07:48,  4.72it/s, loss=0.265, v_num=nk27]
# Validation DataLoader 0:  47%|████████████████▌                  | 1978/4191 [02:46<02:56, 12.57it/s]
# Epoch 0:  78%|████████████████████▉      | 7679/9892 [27:05<07:48,  4.73it/s, loss=0.265, v_num=nk27]
# Epoch 0:  78%|████████████████████▉      | 7680/9892 [27:05<07:48,  4.73it/s, loss=0.265, v_num=nk27]
# Validation DataLoader 0:  47%|████████████████▌                  | 1980/4191 [02:46<03:09, 11.66it/s]
# Epoch 0:  78%|████████████████████▉      | 7681/9892 [27:05<07:47,  4.73it/s, loss=0.265, v_num=nk27]
# Epoch 0:  78%|████████████████████▉      | 7682/9892 [27:05<07:47,  4.73it/s, loss=0.265, v_num=nk27]
# Validation DataLoader 0:  47%|████████████████▌                  | 1982/4191 [02:46<03:01, 12.16it/s]
# Epoch 0:  78%|████████████████████▉      | 7683/9892 [27:05<07:47,  4.73it/s, loss=0.265, v_num=nk27]
# Epoch 0:  78%|████████████████████▉      | 7684/9892 [27:05<07:47,  4.73it/s, loss=0.265, v_num=nk27]
# Validation DataLoader 0:  47%|████████████████▌                  | 1984/4191 [02:46<03:00, 12.22it/s]
# Epoch 0:  78%|████████████████████▉      | 7685/9892 [27:05<07:46,  4.73it/s, loss=0.265, v_num=nk27]
# Epoch 0:  78%|████████████████████▉      | 7686/9892 [27:05<07:46,  4.73it/s, loss=0.265, v_num=nk27]
# Validation DataLoader 0:  47%|████████████████▌                  | 1986/4191 [02:47<03:14, 11.36it/s]
# Epoch 0:  78%|████████████████████▉      | 7687/9892 [27:05<07:46,  4.73it/s, loss=0.265, v_num=nk27]
# Epoch 0:  78%|████████████████████▉      | 7688/9892 [27:05<07:46,  4.73it/s, loss=0.265, v_num=nk27]
# Validation DataLoader 0:  47%|████████████████▌                  | 1988/4191 [02:47<03:14, 11.31it/s]
# Epoch 0:  78%|████████████████████▉      | 7689/9892 [27:05<07:45,  4.73it/s, loss=0.265, v_num=nk27]
# Epoch 0:  78%|████████████████████▉      | 7690/9892 [27:06<07:45,  4.73it/s, loss=0.265, v_num=nk27]
# Validation DataLoader 0:  47%|████████████████▌                  | 1990/4191 [02:47<03:06, 11.78it/s]
# Epoch 0:  78%|████████████████████▉      | 7691/9892 [27:06<07:45,  4.73it/s, loss=0.265, v_num=nk27]
# Epoch 0:  78%|████████████████████▉      | 7692/9892 [27:06<07:45,  4.73it/s, loss=0.265, v_num=nk27]
# Validation DataLoader 0:  48%|████████████████▋                  | 1992/4191 [02:47<03:03, 11.97it/s]
# Epoch 0:  78%|████████████████████▉      | 7693/9892 [27:06<07:44,  4.73it/s, loss=0.265, v_num=nk27]
# Epoch 0:  78%|█████████████████████      | 7694/9892 [27:06<07:44,  4.73it/s, loss=0.265, v_num=nk27]
# Validation DataLoader 0:  48%|████████████████▋                  | 1994/4191 [02:47<03:14, 11.31it/s]
# Epoch 0:  78%|█████████████████████      | 7695/9892 [27:06<07:44,  4.73it/s, loss=0.265, v_num=nk27]
# Epoch 0:  78%|█████████████████████      | 7696/9892 [27:06<07:44,  4.73it/s, loss=0.265, v_num=nk27]
# Validation DataLoader 0:  48%|████████████████▋                  | 1996/4191 [02:48<03:28, 10.52it/s]
# Epoch 0:  78%|█████████████████████      | 7697/9892 [27:06<07:43,  4.73it/s, loss=0.265, v_num=nk27]
# Epoch 0:  78%|█████████████████████      | 7698/9892 [27:06<07:43,  4.73it/s, loss=0.265, v_num=nk27]
# Validation DataLoader 0:  48%|████████████████▋                  | 1998/4191 [02:48<03:48,  9.60it/s]
# Epoch 0:  78%|█████████████████████      | 7699/9892 [27:06<07:43,  4.73it/s, loss=0.265, v_num=nk27]
# Epoch 0:  78%|█████████████████████      | 7700/9892 [27:07<07:43,  4.73it/s, loss=0.265, v_num=nk27]
# Validation DataLoader 0:  48%|████████████████▋                  | 2000/4191 [02:48<03:47,  9.61it/s]
# Epoch 0:  78%|█████████████████████      | 7701/9892 [27:07<07:42,  4.73it/s, loss=0.265, v_num=nk27]
# Epoch 0:  78%|█████████████████████      | 7702/9892 [27:07<07:42,  4.73it/s, loss=0.265, v_num=nk27]
# Validation DataLoader 0:  48%|████████████████▋                  | 2002/4191 [02:48<03:27, 10.56it/s]
# Epoch 0:  78%|█████████████████████      | 7703/9892 [27:07<07:42,  4.73it/s, loss=0.265, v_num=nk27]
# Epoch 0:  78%|█████████████████████      | 7704/9892 [27:07<07:42,  4.73it/s, loss=0.265, v_num=nk27]
# Validation DataLoader 0:  48%|████████████████▋                  | 2004/4191 [02:48<03:14, 11.25it/s]
# Epoch 0:  78%|█████████████████████      | 7705/9892 [27:07<07:41,  4.73it/s, loss=0.265, v_num=nk27]
# Epoch 0:  78%|█████████████████████      | 7706/9892 [27:07<07:41,  4.73it/s, loss=0.265, v_num=nk27]
# Validation DataLoader 0:  48%|████████████████▊                  | 2006/4191 [02:49<03:17, 11.09it/s]
# Epoch 0:  78%|█████████████████████      | 7707/9892 [27:07<07:41,  4.74it/s, loss=0.265, v_num=nk27]
# Epoch 0:  78%|█████████████████████      | 7708/9892 [27:07<07:41,  4.74it/s, loss=0.265, v_num=nk27]
# Validation DataLoader 0:  48%|████████████████▊                  | 2008/4191 [02:49<03:09, 11.54it/s]
# Epoch 0:  78%|█████████████████████      | 7709/9892 [27:07<07:40,  4.74it/s, loss=0.265, v_num=nk27]
# Epoch 0:  78%|█████████████████████      | 7710/9892 [27:07<07:40,  4.74it/s, loss=0.265, v_num=nk27]
# Validation DataLoader 0:  48%|████████████████▊                  | 2010/4191 [02:49<03:00, 12.08it/s]
# Epoch 0:  78%|█████████████████████      | 7711/9892 [27:07<07:40,  4.74it/s, loss=0.265, v_num=nk27]
# Epoch 0:  78%|█████████████████████      | 7712/9892 [27:08<07:40,  4.74it/s, loss=0.265, v_num=nk27]
# Validation DataLoader 0:  48%|████████████████▊                  | 2012/4191 [02:49<03:11, 11.40it/s]
# Epoch 0:  78%|█████████████████████      | 7713/9892 [27:08<07:39,  4.74it/s, loss=0.265, v_num=nk27]
# Epoch 0:  78%|█████████████████████      | 7714/9892 [27:08<07:39,  4.74it/s, loss=0.265, v_num=nk27]
# Validation DataLoader 0:  48%|████████████████▊                  | 2014/4191 [02:49<02:57, 12.30it/s]
# Epoch 0:  78%|█████████████████████      | 7715/9892 [27:08<07:39,  4.74it/s, loss=0.265, v_num=nk27]
# Epoch 0:  78%|█████████████████████      | 7716/9892 [27:08<07:39,  4.74it/s, loss=0.265, v_num=nk27]
# Validation DataLoader 0:  48%|████████████████▊                  | 2016/4191 [02:49<02:48, 12.89it/s]
# Epoch 0:  78%|█████████████████████      | 7717/9892 [27:08<07:38,  4.74it/s, loss=0.265, v_num=nk27]
# Epoch 0:  78%|█████████████████████      | 7718/9892 [27:08<07:38,  4.74it/s, loss=0.265, v_num=nk27]
# Validation DataLoader 0:  48%|████████████████▊                  | 2018/4191 [02:49<02:46, 13.06it/s]
# Epoch 0:  78%|█████████████████████      | 7719/9892 [27:08<07:38,  4.74it/s, loss=0.265, v_num=nk27]
# Epoch 0:  78%|█████████████████████      | 7720/9892 [27:08<07:38,  4.74it/s, loss=0.265, v_num=nk27]
# Validation DataLoader 0:  48%|████████████████▊                  | 2020/4191 [02:50<02:45, 13.09it/s]
# Epoch 0:  78%|█████████████████████      | 7721/9892 [27:08<07:37,  4.74it/s, loss=0.265, v_num=nk27]
# Epoch 0:  78%|█████████████████████      | 7722/9892 [27:08<07:37,  4.74it/s, loss=0.265, v_num=nk27]
# Validation DataLoader 0:  48%|████████████████▉                  | 2022/4191 [02:50<03:06, 11.63it/s]
# Epoch 0:  78%|█████████████████████      | 7723/9892 [27:08<07:37,  4.74it/s, loss=0.265, v_num=nk27]
# Epoch 0:  78%|█████████████████████      | 7724/9892 [27:09<07:37,  4.74it/s, loss=0.265, v_num=nk27]
# Validation DataLoader 0:  48%|████████████████▉                  | 2024/4191 [02:50<03:12, 11.27it/s]
# Epoch 0:  78%|█████████████████████      | 7725/9892 [27:09<07:36,  4.74it/s, loss=0.265, v_num=nk27]
# Epoch 0:  78%|█████████████████████      | 7726/9892 [27:09<07:36,  4.74it/s, loss=0.265, v_num=nk27]
# Validation DataLoader 0:  48%|████████████████▉                  | 2026/4191 [02:50<03:12, 11.27it/s]
# Epoch 0:  78%|█████████████████████      | 7727/9892 [27:09<07:36,  4.74it/s, loss=0.265, v_num=nk27]
# Epoch 0:  78%|█████████████████████      | 7728/9892 [27:09<07:36,  4.74it/s, loss=0.265, v_num=nk27]
# Validation DataLoader 0:  48%|████████████████▉                  | 2028/4191 [02:50<03:04, 11.74it/s]
# Epoch 0:  78%|█████████████████████      | 7729/9892 [27:09<07:36,  4.74it/s, loss=0.265, v_num=nk27]
# Epoch 0:  78%|█████████████████████      | 7730/9892 [27:09<07:35,  4.74it/s, loss=0.265, v_num=nk27]
# Validation DataLoader 0:  48%|████████████████▉                  | 2030/4191 [02:50<03:03, 11.75it/s]
# Epoch 0:  78%|█████████████████████      | 7731/9892 [27:09<07:35,  4.74it/s, loss=0.265, v_num=nk27]
# Epoch 0:  78%|█████████████████████      | 7732/9892 [27:09<07:35,  4.74it/s, loss=0.265, v_num=nk27]
# Validation DataLoader 0:  48%|████████████████▉                  | 2032/4191 [02:51<03:11, 11.29it/s]
# Epoch 0:  78%|█████████████████████      | 7733/9892 [27:09<07:35,  4.74it/s, loss=0.265, v_num=nk27]
# Epoch 0:  78%|█████████████████████      | 7734/9892 [27:09<07:34,  4.75it/s, loss=0.265, v_num=nk27]
# Validation DataLoader 0:  49%|████████████████▉                  | 2034/4191 [02:51<02:58, 12.05it/s]
# Epoch 0:  78%|█████████████████████      | 7735/9892 [27:09<07:34,  4.75it/s, loss=0.265, v_num=nk27]
# Epoch 0:  78%|█████████████████████      | 7736/9892 [27:10<07:34,  4.75it/s, loss=0.265, v_num=nk27]
# Validation DataLoader 0:  49%|█████████████████                  | 2036/4191 [02:51<02:54, 12.38it/s]
# Epoch 0:  78%|█████████████████████      | 7737/9892 [27:10<07:34,  4.75it/s, loss=0.265, v_num=nk27]
# Epoch 0:  78%|█████████████████████      | 7738/9892 [27:10<07:33,  4.75it/s, loss=0.265, v_num=nk27]
# Validation DataLoader 0:  49%|█████████████████                  | 2038/4191 [02:51<02:48, 12.77it/s]
# Epoch 0:  78%|█████████████████████      | 7739/9892 [27:10<07:33,  4.75it/s, loss=0.265, v_num=nk27]
# Epoch 0:  78%|█████████████████████▏     | 7740/9892 [27:10<07:33,  4.75it/s, loss=0.265, v_num=nk27]
# Validation DataLoader 0:  49%|█████████████████                  | 2040/4191 [02:51<02:52, 12.47it/s]
# Epoch 0:  78%|█████████████████████▏     | 7741/9892 [27:10<07:33,  4.75it/s, loss=0.265, v_num=nk27]
# Epoch 0:  78%|█████████████████████▏     | 7742/9892 [27:10<07:32,  4.75it/s, loss=0.265, v_num=nk27]
# Validation DataLoader 0:  49%|█████████████████                  | 2042/4191 [02:51<03:05, 11.58it/s]
# Epoch 0:  78%|█████████████████████▏     | 7743/9892 [27:10<07:32,  4.75it/s, loss=0.265, v_num=nk27]
# Epoch 0:  78%|█████████████████████▏     | 7744/9892 [27:10<07:32,  4.75it/s, loss=0.265, v_num=nk27]
# Validation DataLoader 0:  49%|█████████████████                  | 2044/4191 [02:52<02:59, 11.96it/s]
# Epoch 0:  78%|█████████████████████▏     | 7745/9892 [27:10<07:32,  4.75it/s, loss=0.265, v_num=nk27]
