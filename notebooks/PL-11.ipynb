# %%
DEBUG = False

# %%
EXP = 'PL11'

# %%
import torch
from torch import nn
from torch.nn import functional as F
from torch.utils.data import DataLoader
import pytorch_lightning as pl

import pandas as pd
import numpy as np
import random
import re
import itertools
import argparse

from torch.utils.data import Dataset
import spacy
import ast
from sklearn.model_selection import StratifiedKFold, GroupKFold, KFold

import pickle
import transformers
from transformers import AutoConfig, AutoModel, AutoTokenizer, get_linear_schedule_with_warmup
import warnings
from torch.optim import Adam, SGD, AdamW

import wandb
from pytorch_lightning.loggers import WandbLogger

# %%
pl.seed_everything(42, workers=True)
# Out:
# Global seed set to 42
# 42

# %%
class MyDataset(Dataset):
    def __init__(self, df, tokenizer, max_len=1024, stage='train', rand_prob=0.1, lowup_proba=0.0, swap_proba=0.0):
        self.df = df
        self.max_len = max_len
        self.tokenizer = tokenizer
        self.mask_token = tokenizer.convert_tokens_to_ids(tokenizer.mask_token)
        self.stage = stage
        self.rand_prob = rand_prob
        self.lowup_proba = lowup_proba
        self.swap_proba = swap_proba

        self.essay_id = df['essay_id'].values
        self.input_ids = df['input_ids'].values
        self.attention_mask = df['attention_mask'].values
        self.offset_mapping = df['offset_mapping'].values
        self.token_class_labels = df['token_class_labels'].values
        self.token_scores_labels = df['token_scores_labels'].values
        self.token_examples_mapping = df['token_examples_mapping'].values
        self.examples_scores = df['examples_scores'].values
        self.examples_classes = df['examples_classes'].values    
        
    def __getitem__(self, idx):
        essay_id = self.essay_id[idx]
        offset_mapping = self.offset_mapping[idx]

        token_examples_mapping = self.token_examples_mapping[idx]
        examples_scores = self.examples_scores[idx]
        examples_classes = self.examples_classes[idx]

        token_examples_mapping = torch.tensor(token_examples_mapping, dtype=torch.long)
        examples_scores = torch.tensor(examples_scores + [-1] * (40 - len(examples_scores)), dtype=torch.long)
        examples_classes = torch.tensor(examples_classes + [-1] * (40 - len(examples_classes)), dtype=torch.long)
        
        input_ids = self.input_ids[idx]
        attention_mask = self.attention_mask[idx]
        token_class_labels = self.token_class_labels[idx]
        token_scores_labels = self.token_scores_labels[idx]

        input_ids = torch.tensor(input_ids, dtype=torch.long)
        attention_mask = torch.tensor(attention_mask, dtype=torch.long)
        token_class_labels = torch.tensor(token_class_labels, dtype=torch.long)
        token_scores_labels = torch.tensor(token_scores_labels, dtype=torch.long)

        if self.stage == 'train':
            ix = torch.rand(size=(self.max_len,)) < self.rand_prob
            input_ids[ix] = self.mask_token
        
        return {
            "input_ids": input_ids,
            "attention_mask": attention_mask,
            "token_class_labels": token_class_labels,
            "token_scores_labels": token_scores_labels,
            "token_examples_mapping": token_examples_mapping,
            "examples_scores": examples_scores,
            "examples_classes": examples_classes
        }

    def __len__(self):
        return len(self.df)

# %%
emb_dim = 64

# %%
from transformers import *
import torch.nn as nn
import torch.nn.functional as F

class ResidualLSTM(nn.Module):

    def __init__(self, d_model):
        super(ResidualLSTM, self).__init__()
        self.downsample=nn.Linear(d_model,d_model//2)
        self.LSTM=nn.GRU(d_model//2, d_model//2, num_layers=2, bidirectional=False, dropout=0.2)
        self.dropout1=nn.Dropout(0.2)
        self.norm1= nn.LayerNorm(d_model//2)
        self.linear1=nn.Linear(d_model//2, d_model*4)
        self.linear2=nn.Linear(d_model*4, d_model)
        self.dropout2=nn.Dropout(0.2)
        self.norm2= nn.LayerNorm(d_model)

    def forward(self, x):
        res=x
        x=self.downsample(x)
        x, _ = self.LSTM(x)
        x=self.dropout1(x)
        x=self.norm1(x)
        x=F.relu(self.linear1(x))
        x=self.linear2(x)
        x=self.dropout2(x)
        x=res+x
        return self.norm2(x)
    

class SlidingWindowTransformerModel(nn.Module):
#     def __init__(self, DOWNLOADED_MODEL_PATH, window_size=512):
    def __init__(self, checkpoint, window_size=512):

        super(SlidingWindowTransformerModel, self).__init__()
#         config_model = AutoConfig.from_pretrained(DOWNLOADED_MODEL_PATH+'/config.json')
        config_model = AutoConfig.from_pretrained(checkpoint)

#         self.backbone=AutoModel.from_pretrained(
#                            DOWNLOADED_MODEL_PATH+'/pytorch_model.bin',config=config_model)
        self.backbone=AutoModel.from_pretrained(checkpoint)
        self.nb_features = config_model.hidden_size

#         self.lstm=ResidualLSTM(self.nb_features)
        self.lstm=nn.GRU(self.nb_features, self.nb_features//2, batch_first=True, bidirectional=True)
        
#         self.classification_head=nn.Linear(1024,15)
        self.window_size=window_size

    def forward(self,x,attention_mask):

        B,L=x.shape

        if L>self.window_size:
            x=x.reshape(B,L//self.window_size,self.window_size).reshape(-1,self.window_size)
            attention_mask=attention_mask.reshape(B,L//self.window_size,self.window_size).reshape(-1,self.window_size)
            
        x=self.backbone(input_ids=x,attention_mask=attention_mask,return_dict=False)[0]
        x=x.reshape(B,L,-1)
        x,_=self.lstm(x.permute(1,0,2))
        x=x.permute(1,0,2)
#         x=self.lstm(x.permute(1,0,2)).permute(1,0,2)
#         x=self.classification_head(x)

        return x

# %%
betas = (0.9, 0.999)
eps = 1e-6

# %%
class MyModule(pl.LightningModule):
    def __init__(self, lr, model_checkpoint, num_classes, num_classes_class, emb_dim, betas, eps):
        super().__init__()
        self.lr = lr
        self.num_classes = num_classes
        self.num_classes_class = num_classes_class
        self.emb_dim = emb_dim
        self.name = model_checkpoint
        self.pad_idx = 1 if "roberta" in self.name else 0
        config = AutoConfig.from_pretrained(model_checkpoint, output_hidden_states=True)
        self.transformer = SlidingWindowTransformerModel(model_checkpoint)
        self.nb_features = config.hidden_size
        self.logits = nn.Linear(self.nb_features, num_classes)
        self.example_logits = nn.Linear(self.nb_features + self.emb_dim, num_classes)
        self.class_logits = nn.Linear(self.nb_features, num_classes_class)  
        transformers.logging.set_verbosity_error()
        self.embedding = nn.Embedding(num_classes_class, emb_dim, max_norm=True)
        self.betas = betas
        self.eps = eps
    
    def configure_optimizers(self):
        no_decay = ["bias", "LayerNorm.bias", "LayerNorm.weight"]
        optimizer_parameters = [
            {'params': [p for n, p in self.named_parameters() if not any(nd in n for nd in no_decay)],
             'lr': self.lr, 'weight_decay': 0.01},
            {'params': [p for n, p in self.named_parameters() if any(nd in n for nd in no_decay)],
             'lr': self.lr, 'weight_decay': 0.0}
        ]
        optimizer = AdamW(optimizer_parameters, lr=self.lr, betas=self.betas, eps=self.eps)
        scheduler = get_linear_schedule_with_warmup(
            optimizer,
            num_warmup_steps=100,
            num_training_steps=self.trainer.estimated_stepping_batches,
        )
        scheduler = {"scheduler": scheduler, "interval": "step", "frequency": 1}
        return [optimizer], [scheduler]
                
    def training_step(self, train_batch, batch_idx):
        input_ids, attention_mask, token_scores_labels, token_examples_mapping, \
        examples_scores, examples_classes, token_class_labels = \
            train_batch["input_ids"], train_batch["attention_mask"], train_batch["token_scores_labels"], \
            train_batch['token_examples_mapping'], train_batch['examples_scores'], \
            train_batch['examples_classes'], train_batch['token_class_labels']
        
        features = self.transformer(
            input_ids,
            attention_mask=attention_mask,
        )
        logits = self.logits(features)
        class_logits = self.class_logits(features)
        loss = F.cross_entropy(logits.view(-1, self.num_classes), token_scores_labels.view(-1))
        class_loss = F.cross_entropy(class_logits.view(-1, self.num_classes_class), token_class_labels.view(-1))

        # Convert to examples loss
        bs, ml, nc1 = logits.shape
        
        batch_preds = []
        batch_targs = []
        
        for i in range(bs):
            example_preds = []
            example_targs = []
            num_examples = token_examples_mapping[i].max()
            assert examples_scores[i,num_examples] >= 0 # and examples_scores[i,num_examples+1] < 0 # truncation breaks this
            for j in range(num_examples + 1):
                indices = token_examples_mapping[i] == j
                fts = features[i][indices].mean(dim=0)
                class_idx = examples_classes[i,j]
                emb = self.embedding(class_idx)
                preds = self.example_logits(torch.cat([emb,fts]))
                example_preds.append(preds)
                example_targs.append(examples_scores[i,j].view(1))
                
            example_preds = torch.cat(example_preds, dim=0).view(-1, nc1)
            example_targs = torch.cat(example_targs, dim=0)
            batch_preds.append(example_preds)
            batch_targs.append(example_targs)
        
        batch_preds = torch.cat(batch_preds, dim=0).view(-1, nc1)
        batch_targs = torch.cat(batch_targs, dim=0)
        
        example_loss = F.cross_entropy(batch_preds, batch_targs)
        
#         if self.current_epoch == 0:
    
        total_loss = loss + class_loss + example_loss

        self.log('train_scores_loss', loss)
        self.log('train_classes_loss', class_loss)
        self.log('train_examples_loss', example_loss)
        self.log('train_total_loss', total_loss)

        return total_loss
        
    def validation_step(self, val_batch, batch_idx):
        input_ids, attention_mask, token_scores_labels, token_examples_mapping, \
        examples_scores, examples_classes, token_class_labels = \
            val_batch["input_ids"], val_batch["attention_mask"], val_batch["token_scores_labels"], \
            val_batch['token_examples_mapping'], val_batch['examples_scores'], val_batch['examples_classes'], \
            val_batch['token_class_labels']
        features = self.transformer(
            input_ids,
            attention_mask=attention_mask,
        )
        logits = self.logits(features)        
        class_logits = self.class_logits(features)
        y_pred = F.log_softmax(logits, dim=-1)                                                
        loss = F.cross_entropy(logits.view(-1, self.num_classes), token_scores_labels.view(-1))
        class_loss = F.cross_entropy(class_logits.view(-1, self.num_classes_class), token_class_labels.view(-1))
        self.log('val_loss', loss)
        self.log('val_class_loss', class_loss)
        return {"preds": y_pred,
                "logits": logits,
                "features": features,
                "val_losses": loss,
                "token_examples_mapping": token_examples_mapping,
                "examples_scores": examples_scores,
                "examples_classes": examples_classes}   
    
    def validation_epoch_end(self, validation_step_outputs):

        bs, ml, nc1 = validation_step_outputs[0]["preds"].shape
        ml2 = validation_step_outputs[0]["examples_scores"].shape[-1]
        all_preds = torch.cat([x["logits"] for x in validation_step_outputs], dim=0).view(-1, ml, nc1)
        all_features = torch.cat([x["features"] for x in validation_step_outputs], dim=0).view(-1, ml, self.nb_features)
        all_mappings = torch.cat([x["token_examples_mapping"] for x in validation_step_outputs], dim=0).view(-1, ml)
        all_scores = torch.cat([x["examples_scores"] for x in validation_step_outputs], dim=0).view(-1, ml2)
        all_classes = torch.cat([x["examples_classes"] for x in validation_step_outputs], dim=0).view(-1, ml2)

        num_texts = all_scores.shape[0]        
        
        example_preds = []
        example_targs = []
        
        for i in range(num_texts):
            num_examples = all_mappings[i].max()
            assert all_scores[i,num_examples] >= 0 # and all_scores[i,num_examples+1] < 0 # truncation breaks this
            for j in range(num_examples + 1):
                indices = all_mappings[i] == j
                fts = all_features[i][indices].mean(dim=0)
                class_idx = all_classes[i,j]
                emb = self.embedding(class_idx)
                preds = self.example_logits(torch.cat([emb,fts]))
                example_preds.append(preds)
                example_targs.append(all_scores[i,j].view(1))              
                
        example_preds = torch.cat(example_preds, dim=0).view(-1, nc1)
        example_targs = torch.cat(example_targs, dim=0)
        
        if torch.isnan(example_preds).any() or torch.isinf(example_preds).any():
            print('invalid example_preds')            
        if torch.isnan(example_targs).any() or torch.isinf(example_targs).any():
            print('invalid example_targs')    
            
            
        example_loss = F.cross_entropy(example_preds, example_targs)
        self.log('example_loss', example_loss)
        print(example_loss)
        
    def predict_step(self, val_batch, batch_idx):
        input_ids, attention_mask, token_scores_labels, token_examples_mapping, examples_scores, examples_classes = \
            val_batch["input_ids"], val_batch["attention_mask"], val_batch["token_scores_labels"], \
            val_batch['token_examples_mapping'], val_batch['examples_scores'], val_batch['examples_classes']
        features = self.transformer(
            input_ids,
            attention_mask=attention_mask,
        )
        logits = self.logits(features)
        y_pred = F.softmax(logits, dim=-1)  
        
        bs, ml, nc1 = logits.shape
        ml2 = 40
        
        batch_preds = []
        batch_targs = []
        
        for i in range(bs):
            example_preds = []
            example_targs = []
            num_examples = token_examples_mapping[i].max()
            assert examples_scores[i,num_examples] >= 0 # and examples_scores[i,num_examples+1] < 0 # truncation breaks this
            for j in range(num_examples + 1):               
                indices = token_examples_mapping[i] == j
                fts = features[i][indices].mean(dim=0)
                class_idx = examples_classes[i,j]
                emb = self.embedding(class_idx)
                preds = self.example_logits(torch.cat([emb,fts]))
                example_preds.append(preds)
                example_targs.append(examples_scores[i,j].view(1))   
                
            example_preds = torch.cat(example_preds, dim=0).view(-1, nc1)
            example_targs = torch.cat(example_targs, dim=0)
            batch_preds.append(example_preds)
            batch_targs.append(example_targs)
        
        return batch_preds, batch_targs

# %%
import pickle
with open('processed-deberta-v3-large.pickle', 'rb') as handle:
    pdf = pickle.load(handle)

# %%
tags = ['debug'] if DEBUG else ['train']
if DEBUG: pdf = pdf.sample(n=100, random_state=42)

# %%
df_train = pdf[pdf.fold != 0].reset_index(drop=True)
df_valid = pdf[pdf.fold == 0].reset_index(drop=True)

# %%
project = 'fbck'
run = wandb.init(project=project, tags=tags)
run.log_code()
# Out:
# Changes to your `wandb` environment variables will be ignored because your `wandb` session has already started. For more information on how to modify your settings with `wandb.init()` arguments, please refer to <a href="https://wandb.me/wandb-init" target="_blank">the W&B docs</a>.
# Tracking run with wandb version 0.12.21
# Run data is saved locally in <code>/home/darek/projects/fbck/notebooks/wandb/run-20220726_213442-18yjfeep</code>
# Syncing run <strong><a href="https://wandb.ai/darek/fbck/runs/18yjfeep" target="_blank">apricot-puddle-104</a></strong> to <a href="https://wandb.ai/darek/fbck" target="_blank">Weights & Biases</a> (<a href="https://wandb.me/run" target="_blank">docs</a>)<br/>

# %%
seed = 42
OUTPUT_DIR = '../output'
pl.seed_everything(seed)
# Out:
# Global seed set to 42
# 42

# %%
model_checkpoint = 'microsoft/deberta-v3-large'
max_length = 1024
tokenizer = AutoTokenizer.from_pretrained(model_checkpoint, max_length=max_length, padding='max_length')
bs = 4
lr = 5e-6
grad_acc = 1
epochs = 2 if DEBUG else 4
num_classes = 3
num_classes_class = 8
randmask_proba = 0.15

# %%
train_dataset = MyDataset(
    df_train,
    tokenizer,
    max_len=max_length,
    stage='train',
    rand_prob=randmask_proba
)

valid_dataset = MyDataset(
    df_valid,
    tokenizer,
    max_len=max_length,
    stage='valid',
    rand_prob=randmask_proba
)

# %%
train_loader = DataLoader(train_dataset,
                          batch_size=bs,
                          shuffle=True,
                          num_workers=4, pin_memory=True, drop_last=True)

val_loader = DataLoader(valid_dataset,
                          batch_size=bs,
                          shuffle=False,
                          num_workers=4, pin_memory=True, drop_last=False)

# %%
warnings.filterwarnings("ignore")

# %%
model = MyModule(lr=lr,
                 model_checkpoint=model_checkpoint, 
                 num_classes=num_classes,
                 num_classes_class=num_classes_class,
                 emb_dim=emb_dim,
                 betas=betas,
                 eps=eps,
                )

# %%
wandb_logger = WandbLogger(project=project)

# %%
from pytorch_lightning.callbacks import ModelCheckpoint

checkpoint_callback = ModelCheckpoint(
    save_top_k=1,
    monitor="example_loss",
    mode="min",
    dirpath=f"../output/{EXP}/",
    filename="feedback-{epoch:02d}-{example_loss:.2f}",
)

# %%
trainer = pl.Trainer(accelerator="gpu", 
                     precision=16, 
                     gradient_clip_val=1.,
                     devices=1, 
                     max_epochs=epochs,
                     log_every_n_steps=100, 
                     logger=wandb_logger,
                     default_root_dir=f"../output/{EXP}",
                     callbacks=[checkpoint_callback],
                     accumulate_grad_batches=grad_acc,
                     )
# Out:
# Using 16bit native Automatic Mixed Precision (AMP)
# GPU available: True, used: True
# TPU available: False, using: 0 TPU cores
# IPU available: False, using: 0 IPUs
# HPU available: False, using: 0 HPUs

# %%
trainer.fit(model, train_loader, val_loader)
# Out:
# LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
# Loading `train_dataloader` to estimate number of stepping batches.
#
#   | Name           | Type                          | Params
# -----------------------------------------------------------------
# 0 | transformer    | SlidingWindowTransformerModel | 438 M
# 1 | logits         | Linear                        | 3.1 K
# 2 | example_logits | Linear                        | 3.3 K
# 3 | class_logits   | Linear                        | 8.2 K
# 4 | embedding      | Embedding                     | 512
# -----------------------------------------------------------------
# 438 M     Trainable params
# 0         Non-trainable params
# 438 M     Total params
# 877.504   Total estimated model params size (MB)
# Sanity Checking DataLoader 0: 100%|████████████████████████████████████| 2/2 [00:00<00:00,  2.33it/s]tensor(1.0891, device='cuda:0')
# Epoch 0:  80%|███████████████████████▏     | 838/1048 [05:18<01:19,  2.63it/s, loss=2.64, v_num=feep]
# Validation: 0it [00:00, ?it/s]
# Validation:   0%|                                                            | 0/210 [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|                                               | 0/210 [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|▏                                      | 1/210 [00:00<00:31,  6.54it/s]
# Epoch 0:  80%|███████████████████████▏     | 839/1048 [05:19<01:19,  2.63it/s, loss=2.64, v_num=feep]
# Validation DataLoader 0:   1%|▎                                      | 2/210 [00:00<00:28,  7.28it/s]
# Epoch 0:  80%|███████████████████████▏     | 840/1048 [05:19<01:19,  2.63it/s, loss=2.64, v_num=feep]
# Validation DataLoader 0:   1%|▌                                      | 3/210 [00:00<00:27,  7.52it/s]
# Epoch 0:  80%|███████████████████████▎     | 841/1048 [05:19<01:18,  2.63it/s, loss=2.64, v_num=feep]
# Validation DataLoader 0:   2%|▋                                      | 4/210 [00:00<00:26,  7.82it/s]
# Epoch 0:  80%|███████████████████████▎     | 842/1048 [05:19<01:18,  2.63it/s, loss=2.64, v_num=feep]
# Validation DataLoader 0:   2%|▉                                      | 5/210 [00:00<00:25,  7.99it/s]
# Epoch 0:  80%|███████████████████████▎     | 843/1048 [05:19<01:17,  2.63it/s, loss=2.64, v_num=feep]
# Validation DataLoader 0:   3%|█                                      | 6/210 [00:00<00:25,  8.07it/s]
# Epoch 0:  81%|███████████████████████▎     | 844/1048 [05:20<01:17,  2.64it/s, loss=2.64, v_num=feep]
# Validation DataLoader 0:   3%|█▎                                     | 7/210 [00:00<00:25,  8.01it/s]
# Epoch 0:  81%|███████████████████████▍     | 845/1048 [05:20<01:16,  2.64it/s, loss=2.64, v_num=feep]
# Validation DataLoader 0:   4%|█▍                                     | 8/210 [00:01<00:24,  8.14it/s]
# Epoch 0:  81%|███████████████████████▍     | 846/1048 [05:20<01:16,  2.64it/s, loss=2.64, v_num=feep]
# Validation DataLoader 0:   4%|█▋                                     | 9/210 [00:01<00:24,  8.22it/s]
# Epoch 0:  81%|███████████████████████▍     | 847/1048 [05:20<01:16,  2.64it/s, loss=2.64, v_num=feep]
# Validation DataLoader 0:   5%|█▊                                    | 10/210 [00:01<00:24,  8.24it/s]
# Epoch 0:  81%|███████████████████████▍     | 848/1048 [05:20<01:15,  2.65it/s, loss=2.64, v_num=feep]
# Validation DataLoader 0:   5%|█▉                                    | 11/210 [00:01<00:24,  8.15it/s]
# Epoch 0:  81%|███████████████████████▍     | 849/1048 [05:20<01:15,  2.65it/s, loss=2.64, v_num=feep]
# Validation DataLoader 0:   6%|██▏                                   | 12/210 [00:01<00:24,  8.20it/s]
# Epoch 0:  81%|███████████████████████▌     | 850/1048 [05:20<01:14,  2.65it/s, loss=2.64, v_num=feep]
# Validation DataLoader 0:   6%|██▎                                   | 13/210 [00:01<00:23,  8.25it/s]
# Epoch 0:  81%|███████████████████████▌     | 851/1048 [05:20<01:14,  2.65it/s, loss=2.64, v_num=feep]
# Validation DataLoader 0:   7%|██▌                                   | 14/210 [00:01<00:23,  8.26it/s]
# Epoch 0:  81%|███████████████████████▌     | 852/1048 [05:21<01:13,  2.65it/s, loss=2.64, v_num=feep]
# Validation DataLoader 0:   7%|██▋                                   | 15/210 [00:01<00:23,  8.15it/s]
# Epoch 0:  81%|███████████████████████▌     | 853/1048 [05:21<01:13,  2.66it/s, loss=2.64, v_num=feep]
# Validation DataLoader 0:   8%|██▉                                   | 16/210 [00:01<00:23,  8.20it/s]
# Epoch 0:  81%|███████████████████████▋     | 854/1048 [05:21<01:12,  2.66it/s, loss=2.64, v_num=feep]
# Validation DataLoader 0:   8%|███                                   | 17/210 [00:02<00:23,  8.23it/s]
# Epoch 0:  82%|███████████████████████▋     | 855/1048 [05:21<01:12,  2.66it/s, loss=2.64, v_num=feep]
# Validation DataLoader 0:   9%|███▎                                  | 18/210 [00:02<00:23,  8.29it/s]
# Epoch 0:  82%|███████████████████████▋     | 856/1048 [05:21<01:12,  2.66it/s, loss=2.64, v_num=feep]
# Validation DataLoader 0:   9%|███▍                                  | 19/210 [00:02<00:23,  8.18it/s]
# Epoch 0:  82%|███████████████████████▋     | 857/1048 [05:21<01:11,  2.66it/s, loss=2.64, v_num=feep]
# Validation DataLoader 0:  10%|███▌                                  | 20/210 [00:02<00:22,  8.26it/s]
# Epoch 0:  82%|███████████████████████▋     | 858/1048 [05:21<01:11,  2.67it/s, loss=2.64, v_num=feep]
# Validation DataLoader 0:  10%|███▊                                  | 21/210 [00:02<00:22,  8.31it/s]
# Epoch 0:  82%|███████████████████████▊     | 859/1048 [05:21<01:10,  2.67it/s, loss=2.64, v_num=feep]
# Validation DataLoader 0:  10%|███▉                                  | 22/210 [00:02<00:22,  8.35it/s]
# Epoch 0:  82%|███████████████████████▊     | 860/1048 [05:22<01:10,  2.67it/s, loss=2.64, v_num=feep]
# Validation DataLoader 0:  11%|████▏                                 | 23/210 [00:02<00:22,  8.33it/s]
# Epoch 0:  82%|███████████████████████▊     | 861/1048 [05:22<01:09,  2.67it/s, loss=2.64, v_num=feep]
# Validation DataLoader 0:  11%|████▎                                 | 24/210 [00:02<00:22,  8.14it/s]
# Epoch 0:  82%|███████████████████████▊     | 862/1048 [05:22<01:09,  2.67it/s, loss=2.64, v_num=feep]
# Validation DataLoader 0:  12%|████▌                                 | 25/210 [00:03<00:22,  8.17it/s]
# Epoch 0:  82%|███████████████████████▉     | 863/1048 [05:22<01:09,  2.68it/s, loss=2.64, v_num=feep]
# Validation DataLoader 0:  12%|████▋                                 | 26/210 [00:03<00:22,  8.21it/s]
# Epoch 0:  82%|███████████████████████▉     | 864/1048 [05:22<01:08,  2.68it/s, loss=2.64, v_num=feep]
# Validation DataLoader 0:  13%|████▉                                 | 27/210 [00:03<00:22,  8.22it/s]
# Epoch 0:  83%|███████████████████████▉     | 865/1048 [05:22<01:08,  2.68it/s, loss=2.64, v_num=feep]
# Validation DataLoader 0:  13%|█████                                 | 28/210 [00:03<00:22,  8.11it/s]
# Epoch 0:  83%|███████████████████████▉     | 866/1048 [05:22<01:07,  2.68it/s, loss=2.64, v_num=feep]
# Validation DataLoader 0:  14%|█████▏                                | 29/210 [00:03<00:22,  8.18it/s]
# Epoch 0:  83%|███████████████████████▉     | 867/1048 [05:22<01:07,  2.69it/s, loss=2.64, v_num=feep]
# Validation DataLoader 0:  14%|█████▍                                | 30/210 [00:03<00:21,  8.21it/s]
# Epoch 0:  83%|████████████████████████     | 868/1048 [05:23<01:06,  2.69it/s, loss=2.64, v_num=feep]
# Validation DataLoader 0:  15%|█████▌                                | 31/210 [00:03<00:21,  8.25it/s]
# Epoch 0:  83%|████████████████████████     | 869/1048 [05:23<01:06,  2.69it/s, loss=2.64, v_num=feep]
# Validation DataLoader 0:  15%|█████▊                                | 32/210 [00:03<00:21,  8.20it/s]
# Epoch 0:  83%|████████████████████████     | 870/1048 [05:23<01:06,  2.69it/s, loss=2.64, v_num=feep]
# Validation DataLoader 0:  16%|█████▉                                | 33/210 [00:04<00:21,  8.24it/s]
# Epoch 0:  83%|████████████████████████     | 871/1048 [05:23<01:05,  2.69it/s, loss=2.64, v_num=feep]
# Validation DataLoader 0:  16%|██████▏                               | 34/210 [00:04<00:21,  8.26it/s]
# Epoch 0:  83%|████████████████████████▏    | 872/1048 [05:23<01:05,  2.70it/s, loss=2.64, v_num=feep]
# Validation DataLoader 0:  17%|██████▎                               | 35/210 [00:04<00:21,  8.29it/s]
# Epoch 0:  83%|████████████████████████▏    | 873/1048 [05:23<01:04,  2.70it/s, loss=2.64, v_num=feep]
# Validation DataLoader 0:  17%|██████▌                               | 36/210 [00:04<00:21,  8.24it/s]
# Epoch 0:  83%|████████████████████████▏    | 874/1048 [05:23<01:04,  2.70it/s, loss=2.64, v_num=feep]
# Validation DataLoader 0:  18%|██████▋                               | 37/210 [00:04<00:20,  8.28it/s]
# Epoch 0:  83%|████████████████████████▏    | 875/1048 [05:23<01:04,  2.70it/s, loss=2.64, v_num=feep]
# Validation DataLoader 0:  18%|██████▉                               | 38/210 [00:04<00:20,  8.30it/s]
# Epoch 0:  84%|████████████████████████▏    | 876/1048 [05:23<01:03,  2.70it/s, loss=2.64, v_num=feep]
# Validation DataLoader 0:  19%|███████                               | 39/210 [00:04<00:20,  8.28it/s]
# Epoch 0:  84%|████████████████████████▎    | 877/1048 [05:24<01:03,  2.71it/s, loss=2.64, v_num=feep]
# Validation DataLoader 0:  19%|███████▏                              | 40/210 [00:04<00:20,  8.16it/s]
# Epoch 0:  84%|████████████████████████▎    | 878/1048 [05:24<01:02,  2.71it/s, loss=2.64, v_num=feep]
# Validation DataLoader 0:  20%|███████▍                              | 41/210 [00:05<00:20,  8.21it/s]
# Epoch 0:  84%|████████████████████████▎    | 879/1048 [05:24<01:02,  2.71it/s, loss=2.64, v_num=feep]
# Validation DataLoader 0:  20%|███████▌                              | 42/210 [00:05<00:20,  8.27it/s]
# Epoch 0:  84%|████████████████████████▎    | 880/1048 [05:24<01:01,  2.71it/s, loss=2.64, v_num=feep]
# Validation DataLoader 0:  20%|███████▊                              | 43/210 [00:05<00:20,  8.27it/s]
# Epoch 0:  84%|████████████████████████▍    | 881/1048 [05:24<01:01,  2.71it/s, loss=2.64, v_num=feep]
# Validation DataLoader 0:  21%|███████▉                              | 44/210 [00:05<00:20,  8.17it/s]
# Epoch 0:  84%|████████████████████████▍    | 882/1048 [05:24<01:01,  2.72it/s, loss=2.64, v_num=feep]
# Validation DataLoader 0:  21%|████████▏                             | 45/210 [00:05<00:19,  8.25it/s]
# Epoch 0:  84%|████████████████████████▍    | 883/1048 [05:24<01:00,  2.72it/s, loss=2.64, v_num=feep]
# Validation DataLoader 0:  22%|████████▎                             | 46/210 [00:05<00:19,  8.31it/s]
# Epoch 0:  84%|████████████████████████▍    | 884/1048 [05:24<01:00,  2.72it/s, loss=2.64, v_num=feep]
# Validation DataLoader 0:  22%|████████▌                             | 47/210 [00:05<00:19,  8.36it/s]
# Epoch 0:  84%|████████████████████████▍    | 885/1048 [05:25<00:59,  2.72it/s, loss=2.64, v_num=feep]
# Validation DataLoader 0:  23%|████████▋                             | 48/210 [00:05<00:19,  8.37it/s]
# Epoch 0:  85%|████████████████████████▌    | 886/1048 [05:25<00:59,  2.72it/s, loss=2.64, v_num=feep]
# Validation DataLoader 0:  23%|████████▊                             | 49/210 [00:05<00:19,  8.22it/s]
# Epoch 0:  85%|████████████████████████▌    | 887/1048 [05:25<00:59,  2.73it/s, loss=2.64, v_num=feep]
# Validation DataLoader 0:  24%|█████████                             | 50/210 [00:06<00:19,  8.22it/s]
# Epoch 0:  85%|████████████████████████▌    | 888/1048 [05:25<00:58,  2.73it/s, loss=2.64, v_num=feep]
# Validation DataLoader 0:  24%|█████████▏                            | 51/210 [00:06<00:19,  8.27it/s]
# Epoch 0:  85%|████████████████████████▌    | 889/1048 [05:25<00:58,  2.73it/s, loss=2.64, v_num=feep]
# Validation DataLoader 0:  25%|█████████▍                            | 52/210 [00:06<00:19,  8.26it/s]
# Epoch 0:  85%|████████████████████████▋    | 890/1048 [05:25<00:57,  2.73it/s, loss=2.64, v_num=feep]
# Validation DataLoader 0:  25%|█████████▌                            | 53/210 [00:06<00:19,  8.23it/s]
# Epoch 0:  85%|████████████████████████▋    | 891/1048 [05:25<00:57,  2.73it/s, loss=2.64, v_num=feep]
# Validation DataLoader 0:  26%|█████████▊                            | 54/210 [00:06<00:18,  8.31it/s]
# Epoch 0:  85%|████████████████████████▋    | 892/1048 [05:25<00:56,  2.74it/s, loss=2.64, v_num=feep]
# Validation DataLoader 0:  26%|█████████▉                            | 55/210 [00:06<00:18,  8.31it/s]
# Epoch 0:  85%|████████████████████████▋    | 893/1048 [05:26<00:56,  2.74it/s, loss=2.64, v_num=feep]
# Validation DataLoader 0:  27%|██████████▏                           | 56/210 [00:06<00:18,  8.35it/s]
# Epoch 0:  85%|████████████████████████▋    | 894/1048 [05:26<00:56,  2.74it/s, loss=2.64, v_num=feep]
# Validation DataLoader 0:  27%|██████████▎                           | 57/210 [00:06<00:18,  8.28it/s]
# Epoch 0:  85%|████████████████████████▊    | 895/1048 [05:26<00:55,  2.74it/s, loss=2.64, v_num=feep]
# Validation DataLoader 0:  28%|██████████▍                           | 58/210 [00:07<00:18,  8.33it/s]
# Epoch 0:  85%|████████████████████████▊    | 896/1048 [05:26<00:55,  2.75it/s, loss=2.64, v_num=feep]
# Validation DataLoader 0:  28%|██████████▋                           | 59/210 [00:07<00:18,  8.33it/s]
# Epoch 0:  86%|████████████████████████▊    | 897/1048 [05:26<00:54,  2.75it/s, loss=2.64, v_num=feep]
# Validation DataLoader 0:  29%|██████████▊                           | 60/210 [00:07<00:17,  8.36it/s]
# Epoch 0:  86%|████████████████████████▊    | 898/1048 [05:26<00:54,  2.75it/s, loss=2.64, v_num=feep]
# Validation DataLoader 0:  29%|███████████                           | 61/210 [00:07<00:18,  8.16it/s]
# Epoch 0:  86%|████████████████████████▉    | 899/1048 [05:26<00:54,  2.75it/s, loss=2.64, v_num=feep]
# Validation DataLoader 0:  30%|███████████▏                          | 62/210 [00:07<00:17,  8.24it/s]
# Epoch 0:  86%|████████████████████████▉    | 900/1048 [05:26<00:53,  2.75it/s, loss=2.64, v_num=feep]
# Validation DataLoader 0:  30%|███████████▍                          | 63/210 [00:07<00:17,  8.29it/s]
# Epoch 0:  86%|████████████████████████▉    | 901/1048 [05:26<00:53,  2.76it/s, loss=2.64, v_num=feep]
# Validation DataLoader 0:  30%|███████████▌                          | 64/210 [00:07<00:17,  8.33it/s]
# Epoch 0:  86%|████████████████████████▉    | 902/1048 [05:27<00:52,  2.76it/s, loss=2.64, v_num=feep]
# Validation DataLoader 0:  31%|███████████▊                          | 65/210 [00:07<00:17,  8.36it/s]
# Epoch 0:  86%|████████████████████████▉    | 903/1048 [05:27<00:52,  2.76it/s, loss=2.64, v_num=feep]
# Validation DataLoader 0:  31%|███████████▉                          | 66/210 [00:08<00:17,  8.22it/s]
# Epoch 0:  86%|█████████████████████████    | 904/1048 [05:27<00:52,  2.76it/s, loss=2.64, v_num=feep]
# Validation DataLoader 0:  32%|████████████                          | 67/210 [00:08<00:17,  8.29it/s]
# Epoch 0:  86%|█████████████████████████    | 905/1048 [05:27<00:51,  2.76it/s, loss=2.64, v_num=feep]
# Validation DataLoader 0:  32%|████████████▎                         | 68/210 [00:08<00:17,  8.31it/s]
# Epoch 0:  86%|█████████████████████████    | 906/1048 [05:27<00:51,  2.77it/s, loss=2.64, v_num=feep]
# Validation DataLoader 0:  33%|████████████▍                         | 69/210 [00:08<00:16,  8.30it/s]
# Epoch 0:  87%|█████████████████████████    | 907/1048 [05:27<00:50,  2.77it/s, loss=2.64, v_num=feep]
# Validation DataLoader 0:  33%|████████████▋                         | 70/210 [00:08<00:17,  8.13it/s]
# Epoch 0:  87%|█████████████████████████▏   | 908/1048 [05:27<00:50,  2.77it/s, loss=2.64, v_num=feep]
# Validation DataLoader 0:  34%|████████████▊                         | 71/210 [00:08<00:16,  8.18it/s]
# Epoch 0:  87%|█████████████████████████▏   | 909/1048 [05:27<00:50,  2.77it/s, loss=2.64, v_num=feep]
# Validation DataLoader 0:  34%|█████████████                         | 72/210 [00:08<00:16,  8.26it/s]
# Epoch 0:  87%|█████████████████████████▏   | 910/1048 [05:28<00:49,  2.77it/s, loss=2.64, v_num=feep]
# Validation DataLoader 0:  35%|█████████████▏                        | 73/210 [00:08<00:16,  8.31it/s]
# Epoch 0:  87%|█████████████████████████▏   | 911/1048 [05:28<00:49,  2.78it/s, loss=2.64, v_num=feep]
# Validation DataLoader 0:  35%|█████████████▍                        | 74/210 [00:09<00:16,  8.21it/s]
# Epoch 0:  87%|█████████████████████████▏   | 912/1048 [05:28<00:48,  2.78it/s, loss=2.64, v_num=feep]
# Validation DataLoader 0:  36%|█████████████▌                        | 75/210 [00:09<00:16,  8.26it/s]
# Epoch 0:  87%|█████████████████████████▎   | 913/1048 [05:28<00:48,  2.78it/s, loss=2.64, v_num=feep]
# Validation DataLoader 0:  36%|█████████████▊                        | 76/210 [00:09<00:16,  8.21it/s]
# Epoch 0:  87%|█████████████████████████▎   | 914/1048 [05:28<00:48,  2.78it/s, loss=2.64, v_num=feep]
# Validation DataLoader 0:  37%|█████████████▉                        | 77/210 [00:09<00:16,  8.27it/s]
# Epoch 0:  87%|█████████████████████████▎   | 915/1048 [05:28<00:47,  2.78it/s, loss=2.64, v_num=feep]
# Validation DataLoader 0:  37%|██████████████                        | 78/210 [00:09<00:16,  8.18it/s]
# Epoch 0:  87%|█████████████████████████▎   | 916/1048 [05:28<00:47,  2.79it/s, loss=2.64, v_num=feep]
# Validation DataLoader 0:  38%|██████████████▎                       | 79/210 [00:09<00:15,  8.21it/s]
# Epoch 0:  88%|█████████████████████████▍   | 917/1048 [05:28<00:46,  2.79it/s, loss=2.64, v_num=feep]
# Validation DataLoader 0:  38%|██████████████▍                       | 80/210 [00:09<00:15,  8.25it/s]
# Epoch 0:  88%|█████████████████████████▍   | 918/1048 [05:29<00:46,  2.79it/s, loss=2.64, v_num=feep]
# Validation DataLoader 0:  39%|██████████████▋                       | 81/210 [00:09<00:15,  8.32it/s]
# Epoch 0:  88%|█████████████████████████▍   | 919/1048 [05:29<00:46,  2.79it/s, loss=2.64, v_num=feep]
# Validation DataLoader 0:  39%|██████████████▊                       | 82/210 [00:09<00:15,  8.25it/s]
# Epoch 0:  88%|█████████████████████████▍   | 920/1048 [05:29<00:45,  2.79it/s, loss=2.64, v_num=feep]
# Validation DataLoader 0:  40%|███████████████                       | 83/210 [00:10<00:15,  8.30it/s]
# Epoch 0:  88%|█████████████████████████▍   | 921/1048 [05:29<00:45,  2.80it/s, loss=2.64, v_num=feep]
# Validation DataLoader 0:  40%|███████████████▏                      | 84/210 [00:10<00:15,  8.30it/s]
# Epoch 0:  88%|█████████████████████████▌   | 922/1048 [05:29<00:45,  2.80it/s, loss=2.64, v_num=feep]
# Validation DataLoader 0:  40%|███████████████▍                      | 85/210 [00:10<00:14,  8.34it/s]
# Epoch 0:  88%|█████████████████████████▌   | 923/1048 [05:29<00:44,  2.80it/s, loss=2.64, v_num=feep]
# Validation DataLoader 0:  41%|███████████████▌                      | 86/210 [00:10<00:14,  8.37it/s]
# Epoch 0:  88%|█████████████████████████▌   | 924/1048 [05:29<00:44,  2.80it/s, loss=2.64, v_num=feep]
# Validation DataLoader 0:  41%|███████████████▋                      | 87/210 [00:10<00:14,  8.29it/s]
# Epoch 0:  88%|█████████████████████████▌   | 925/1048 [05:29<00:43,  2.80it/s, loss=2.64, v_num=feep]
# Validation DataLoader 0:  42%|███████████████▉                      | 88/210 [00:10<00:14,  8.33it/s]
# Epoch 0:  88%|█████████████████████████▌   | 926/1048 [05:30<00:43,  2.81it/s, loss=2.64, v_num=feep]
# Validation DataLoader 0:  42%|████████████████                      | 89/210 [00:10<00:14,  8.38it/s]
# Epoch 0:  88%|█████████████████████████▋   | 927/1048 [05:30<00:43,  2.81it/s, loss=2.64, v_num=feep]
# Validation DataLoader 0:  43%|████████████████▎                     | 90/210 [00:10<00:14,  8.41it/s]
# Epoch 0:  89%|█████████████████████████▋   | 928/1048 [05:30<00:42,  2.81it/s, loss=2.64, v_num=feep]
# Validation DataLoader 0:  43%|████████████████▍                     | 91/210 [00:11<00:14,  8.28it/s]
# Epoch 0:  89%|█████████████████████████▋   | 929/1048 [05:30<00:42,  2.81it/s, loss=2.64, v_num=feep]
# Validation DataLoader 0:  44%|████████████████▋                     | 92/210 [00:11<00:14,  8.29it/s]
# Epoch 0:  89%|█████████████████████████▋   | 930/1048 [05:30<00:41,  2.81it/s, loss=2.64, v_num=feep]
# Validation DataLoader 0:  44%|████████████████▊                     | 93/210 [00:11<00:14,  8.30it/s]
# Epoch 0:  89%|█████████████████████████▊   | 931/1048 [05:30<00:41,  2.82it/s, loss=2.64, v_num=feep]
# Validation DataLoader 0:  45%|█████████████████                     | 94/210 [00:11<00:13,  8.30it/s]
# Epoch 0:  89%|█████████████████████████▊   | 932/1048 [05:30<00:41,  2.82it/s, loss=2.64, v_num=feep]
# Validation DataLoader 0:  45%|█████████████████▏                    | 95/210 [00:11<00:14,  8.19it/s]
# Epoch 0:  89%|█████████████████████████▊   | 933/1048 [05:30<00:40,  2.82it/s, loss=2.64, v_num=feep]
# Validation DataLoader 0:  46%|█████████████████▎                    | 96/210 [00:11<00:13,  8.26it/s]
# Epoch 0:  89%|█████████████████████████▊   | 934/1048 [05:30<00:40,  2.82it/s, loss=2.64, v_num=feep]
# Validation DataLoader 0:  46%|█████████████████▌                    | 97/210 [00:11<00:13,  8.25it/s]
# Epoch 0:  89%|█████████████████████████▊   | 935/1048 [05:31<00:40,  2.82it/s, loss=2.64, v_num=feep]
# Validation DataLoader 0:  47%|█████████████████▋                    | 98/210 [00:11<00:13,  8.28it/s]
# Epoch 0:  89%|█████████████████████████▉   | 936/1048 [05:31<00:39,  2.83it/s, loss=2.64, v_num=feep]
# Validation DataLoader 0:  47%|█████████████████▉                    | 99/210 [00:12<00:13,  8.18it/s]
# Epoch 0:  89%|█████████████████████████▉   | 937/1048 [05:31<00:39,  2.83it/s, loss=2.64, v_num=feep]
# Validation DataLoader 0:  48%|█████████████████▌                   | 100/210 [00:12<00:13,  8.26it/s]
# Epoch 0:  90%|█████████████████████████▉   | 938/1048 [05:31<00:38,  2.83it/s, loss=2.64, v_num=feep]
# Validation DataLoader 0:  48%|█████████████████▊                   | 101/210 [00:12<00:13,  8.26it/s]
# Epoch 0:  90%|█████████████████████████▉   | 939/1048 [05:31<00:38,  2.83it/s, loss=2.64, v_num=feep]
# Validation DataLoader 0:  49%|█████████████████▉                   | 102/210 [00:12<00:13,  8.28it/s]
# Epoch 0:  90%|██████████████████████████   | 940/1048 [05:31<00:38,  2.83it/s, loss=2.64, v_num=feep]
# Validation DataLoader 0:  49%|██████████████████▏                  | 103/210 [00:12<00:13,  8.20it/s]
# Epoch 0:  90%|██████████████████████████   | 941/1048 [05:31<00:37,  2.84it/s, loss=2.64, v_num=feep]
# Validation DataLoader 0:  50%|██████████████████▎                  | 104/210 [00:12<00:12,  8.28it/s]
# Epoch 0:  90%|██████████████████████████   | 942/1048 [05:31<00:37,  2.84it/s, loss=2.64, v_num=feep]
# Validation DataLoader 0:  50%|██████████████████▌                  | 105/210 [00:12<00:12,  8.31it/s]
# Epoch 0:  90%|██████████████████████████   | 943/1048 [05:32<00:36,  2.84it/s, loss=2.64, v_num=feep]
# Validation DataLoader 0:  50%|██████████████████▋                  | 106/210 [00:12<00:12,  8.32it/s]
# Epoch 0:  90%|██████████████████████████   | 944/1048 [05:32<00:36,  2.84it/s, loss=2.64, v_num=feep]
# Validation DataLoader 0:  51%|██████████████████▊                  | 107/210 [00:12<00:12,  8.36it/s]
# Epoch 0:  90%|██████████████████████████▏  | 945/1048 [05:32<00:36,  2.84it/s, loss=2.64, v_num=feep]
# Validation DataLoader 0:  51%|███████████████████                  | 108/210 [00:13<00:12,  8.21it/s]
# Epoch 0:  90%|██████████████████████████▏  | 946/1048 [05:32<00:35,  2.85it/s, loss=2.64, v_num=feep]
# Validation DataLoader 0:  52%|███████████████████▏                 | 109/210 [00:13<00:12,  8.25it/s]
# Epoch 0:  90%|██████████████████████████▏  | 947/1048 [05:32<00:35,  2.85it/s, loss=2.64, v_num=feep]
# Validation DataLoader 0:  52%|███████████████████▍                 | 110/210 [00:13<00:12,  8.24it/s]
# Epoch 0:  90%|██████████████████████████▏  | 948/1048 [05:32<00:35,  2.85it/s, loss=2.64, v_num=feep]
# Validation DataLoader 0:  53%|███████████████████▌                 | 111/210 [00:13<00:11,  8.28it/s]
# Epoch 0:  91%|██████████████████████████▎  | 949/1048 [05:32<00:34,  2.85it/s, loss=2.64, v_num=feep]
# Validation DataLoader 0:  53%|███████████████████▋                 | 112/210 [00:13<00:11,  8.22it/s]
# Epoch 0:  91%|██████████████████████████▎  | 950/1048 [05:32<00:34,  2.85it/s, loss=2.64, v_num=feep]
# Validation DataLoader 0:  54%|███████████████████▉                 | 113/210 [00:13<00:11,  8.28it/s]
# Epoch 0:  91%|██████████████████████████▎  | 951/1048 [05:33<00:33,  2.86it/s, loss=2.64, v_num=feep]
# Validation DataLoader 0:  54%|████████████████████                 | 114/210 [00:13<00:11,  8.30it/s]
# Epoch 0:  91%|██████████████████████████▎  | 952/1048 [05:33<00:33,  2.86it/s, loss=2.64, v_num=feep]
# Validation DataLoader 0:  55%|████████████████████▎                | 115/210 [00:13<00:11,  8.32it/s]
# Epoch 0:  91%|██████████████████████████▎  | 953/1048 [05:33<00:33,  2.86it/s, loss=2.64, v_num=feep]
# Validation DataLoader 0:  55%|████████████████████▍                | 116/210 [00:14<00:11,  8.18it/s]
# Epoch 0:  91%|██████████████████████████▍  | 954/1048 [05:33<00:32,  2.86it/s, loss=2.64, v_num=feep]
# Validation DataLoader 0:  56%|████████████████████▌                | 117/210 [00:14<00:11,  8.23it/s]
# Epoch 0:  91%|██████████████████████████▍  | 955/1048 [05:33<00:32,  2.86it/s, loss=2.64, v_num=feep]
# Validation DataLoader 0:  56%|████████████████████▊                | 118/210 [00:14<00:11,  8.26it/s]
# Epoch 0:  91%|██████████████████████████▍  | 956/1048 [05:33<00:32,  2.87it/s, loss=2.64, v_num=feep]
# Validation DataLoader 0:  57%|████████████████████▉                | 119/210 [00:14<00:10,  8.31it/s]
# Epoch 0:  91%|██████████████████████████▍  | 957/1048 [05:33<00:31,  2.87it/s, loss=2.64, v_num=feep]
# Validation DataLoader 0:  57%|█████████████████████▏               | 120/210 [00:14<00:10,  8.22it/s]
# Epoch 0:  91%|██████████████████████████▌  | 958/1048 [05:33<00:31,  2.87it/s, loss=2.64, v_num=feep]
# Validation DataLoader 0:  58%|█████████████████████▎               | 121/210 [00:14<00:10,  8.28it/s]
# Epoch 0:  92%|██████████████████████████▌  | 959/1048 [05:34<00:30,  2.87it/s, loss=2.64, v_num=feep]
# Validation DataLoader 0:  58%|█████████████████████▍               | 122/210 [00:14<00:10,  8.31it/s]
# Epoch 0:  92%|██████████████████████████▌  | 960/1048 [05:34<00:30,  2.87it/s, loss=2.64, v_num=feep]
# Validation DataLoader 0:  59%|█████████████████████▋               | 123/210 [00:14<00:10,  8.34it/s]
# Epoch 0:  92%|██████████████████████████▌  | 961/1048 [05:34<00:30,  2.88it/s, loss=2.64, v_num=feep]
# Validation DataLoader 0:  59%|█████████████████████▊               | 124/210 [00:15<00:10,  8.22it/s]
# Epoch 0:  92%|██████████████████████████▌  | 962/1048 [05:34<00:29,  2.88it/s, loss=2.64, v_num=feep]
# Validation DataLoader 0:  60%|██████████████████████               | 125/210 [00:15<00:10,  8.25it/s]
# Epoch 0:  92%|██████████████████████████▋  | 963/1048 [05:34<00:29,  2.88it/s, loss=2.64, v_num=feep]
# Validation DataLoader 0:  60%|██████████████████████▏              | 126/210 [00:15<00:10,  8.27it/s]
# Epoch 0:  92%|██████████████████████████▋  | 964/1048 [05:34<00:29,  2.88it/s, loss=2.64, v_num=feep]
# Validation DataLoader 0:  60%|██████████████████████▍              | 127/210 [00:15<00:09,  8.31it/s]
# Epoch 0:  92%|██████████████████████████▋  | 965/1048 [05:34<00:28,  2.88it/s, loss=2.64, v_num=feep]
# Validation DataLoader 0:  61%|██████████████████████▌              | 128/210 [00:15<00:09,  8.34it/s]
# Epoch 0:  92%|██████████████████████████▋  | 966/1048 [05:34<00:28,  2.88it/s, loss=2.64, v_num=feep]
# Validation DataLoader 0:  61%|██████████████████████▋              | 129/210 [00:15<00:09,  8.17it/s]
# Epoch 0:  92%|██████████████████████████▊  | 967/1048 [05:34<00:28,  2.89it/s, loss=2.64, v_num=feep]
# Validation DataLoader 0:  62%|██████████████████████▉              | 130/210 [00:15<00:09,  8.24it/s]
# Epoch 0:  92%|██████████████████████████▊  | 968/1048 [05:35<00:27,  2.89it/s, loss=2.64, v_num=feep]
# Validation DataLoader 0:  62%|███████████████████████              | 131/210 [00:15<00:09,  8.29it/s]
# Epoch 0:  92%|██████████████████████████▊  | 969/1048 [05:35<00:27,  2.89it/s, loss=2.64, v_num=feep]
# Validation DataLoader 0:  63%|███████████████████████▎             | 132/210 [00:16<00:09,  8.32it/s]
# Epoch 0:  93%|██████████████████████████▊  | 970/1048 [05:35<00:26,  2.89it/s, loss=2.64, v_num=feep]
# Validation DataLoader 0:  63%|███████████████████████▍             | 133/210 [00:16<00:09,  8.24it/s]
# Epoch 0:  93%|██████████████████████████▊  | 971/1048 [05:35<00:26,  2.89it/s, loss=2.64, v_num=feep]
# Validation DataLoader 0:  64%|███████████████████████▌             | 134/210 [00:16<00:09,  8.29it/s]
# Epoch 0:  93%|██████████████████████████▉  | 972/1048 [05:35<00:26,  2.90it/s, loss=2.64, v_num=feep]
# Validation DataLoader 0:  64%|███████████████████████▊             | 135/210 [00:16<00:09,  8.30it/s]
# Epoch 0:  93%|██████████████████████████▉  | 973/1048 [05:35<00:25,  2.90it/s, loss=2.64, v_num=feep]
# Validation DataLoader 0:  65%|███████████████████████▉             | 136/210 [00:16<00:08,  8.32it/s]
# Epoch 0:  93%|██████████████████████████▉  | 974/1048 [05:35<00:25,  2.90it/s, loss=2.64, v_num=feep]
# Validation DataLoader 0:  65%|████████████████████████▏            | 137/210 [00:16<00:08,  8.25it/s]
# Epoch 0:  93%|██████████████████████████▉  | 975/1048 [05:35<00:25,  2.90it/s, loss=2.64, v_num=feep]
# Validation DataLoader 0:  66%|████████████████████████▎            | 138/210 [00:16<00:08,  8.28it/s]
# Epoch 0:  93%|███████████████████████████  | 976/1048 [05:36<00:24,  2.90it/s, loss=2.64, v_num=feep]
# Validation DataLoader 0:  66%|████████████████████████▍            | 139/210 [00:16<00:08,  8.30it/s]
# Epoch 0:  93%|███████████████████████████  | 977/1048 [05:36<00:24,  2.91it/s, loss=2.64, v_num=feep]
# Validation DataLoader 0:  67%|████████████████████████▋            | 140/210 [00:16<00:08,  8.32it/s]
# Epoch 0:  93%|███████████████████████████  | 978/1048 [05:36<00:24,  2.91it/s, loss=2.64, v_num=feep]
# Validation DataLoader 0:  67%|████████████████████████▊            | 141/210 [00:17<00:08,  8.27it/s]
# Epoch 0:  93%|███████████████████████████  | 979/1048 [05:36<00:23,  2.91it/s, loss=2.64, v_num=feep]
# Validation DataLoader 0:  68%|█████████████████████████            | 142/210 [00:17<00:08,  8.30it/s]
# Epoch 0:  94%|███████████████████████████  | 980/1048 [05:36<00:23,  2.91it/s, loss=2.64, v_num=feep]
# Validation DataLoader 0:  68%|█████████████████████████▏           | 143/210 [00:17<00:08,  8.31it/s]
# Epoch 0:  94%|███████████████████████████▏ | 981/1048 [05:36<00:22,  2.91it/s, loss=2.64, v_num=feep]
# Validation DataLoader 0:  69%|█████████████████████████▎           | 144/210 [00:17<00:07,  8.33it/s]
# Epoch 0:  94%|███████████████████████████▏ | 982/1048 [05:36<00:22,  2.92it/s, loss=2.64, v_num=feep]
# Validation DataLoader 0:  69%|█████████████████████████▌           | 145/210 [00:17<00:07,  8.26it/s]
# Epoch 0:  94%|███████████████████████████▏ | 983/1048 [05:36<00:22,  2.92it/s, loss=2.64, v_num=feep]
# Validation DataLoader 0:  70%|█████████████████████████▋           | 146/210 [00:17<00:07,  8.29it/s]
# Epoch 0:  94%|███████████████████████████▏ | 984/1048 [05:37<00:21,  2.92it/s, loss=2.64, v_num=feep]
# Validation DataLoader 0:  70%|█████████████████████████▉           | 147/210 [00:17<00:07,  8.31it/s]
# Epoch 0:  94%|███████████████████████████▎ | 985/1048 [05:37<00:21,  2.92it/s, loss=2.64, v_num=feep]
# Validation DataLoader 0:  70%|██████████████████████████           | 148/210 [00:17<00:07,  8.32it/s]
# Epoch 0:  94%|███████████████████████████▎ | 986/1048 [05:37<00:21,  2.92it/s, loss=2.64, v_num=feep]
# Validation DataLoader 0:  71%|██████████████████████████▎          | 149/210 [00:18<00:07,  8.34it/s]
# Epoch 0:  94%|███████████████████████████▎ | 987/1048 [05:37<00:20,  2.93it/s, loss=2.64, v_num=feep]
# Validation DataLoader 0:  71%|██████████████████████████▍          | 150/210 [00:18<00:07,  8.26it/s]
# Epoch 0:  94%|███████████████████████████▎ | 988/1048 [05:37<00:20,  2.93it/s, loss=2.64, v_num=feep]
# Validation DataLoader 0:  72%|██████████████████████████▌          | 151/210 [00:18<00:07,  8.26it/s]
# Epoch 0:  94%|███████████████████████████▎ | 989/1048 [05:37<00:20,  2.93it/s, loss=2.64, v_num=feep]
# Validation DataLoader 0:  72%|██████████████████████████▊          | 152/210 [00:18<00:07,  8.28it/s]
# Epoch 0:  94%|███████████████████████████▍ | 990/1048 [05:37<00:19,  2.93it/s, loss=2.64, v_num=feep]
# Validation DataLoader 0:  73%|██████████████████████████▉          | 153/210 [00:18<00:06,  8.29it/s]
# Epoch 0:  95%|███████████████████████████▍ | 991/1048 [05:37<00:19,  2.93it/s, loss=2.64, v_num=feep]
# Validation DataLoader 0:  73%|███████████████████████████▏         | 154/210 [00:18<00:06,  8.22it/s]
# Epoch 0:  95%|███████████████████████████▍ | 992/1048 [05:37<00:19,  2.93it/s, loss=2.64, v_num=feep]
# Validation DataLoader 0:  74%|███████████████████████████▎         | 155/210 [00:18<00:06,  8.27it/s]
# Epoch 0:  95%|███████████████████████████▍ | 993/1048 [05:38<00:18,  2.94it/s, loss=2.64, v_num=feep]
# Validation DataLoader 0:  74%|███████████████████████████▍         | 156/210 [00:18<00:06,  8.31it/s]
# Epoch 0:  95%|███████████████████████████▌ | 994/1048 [05:38<00:18,  2.94it/s, loss=2.64, v_num=feep]
# Validation DataLoader 0:  75%|███████████████████████████▋         | 157/210 [00:19<00:06,  8.33it/s]
# Epoch 0:  95%|███████████████████████████▌ | 995/1048 [05:38<00:18,  2.94it/s, loss=2.64, v_num=feep]
# Validation DataLoader 0:  75%|███████████████████████████▊         | 158/210 [00:19<00:06,  8.28it/s]
# Epoch 0:  95%|███████████████████████████▌ | 996/1048 [05:38<00:17,  2.94it/s, loss=2.64, v_num=feep]
# Validation DataLoader 0:  76%|████████████████████████████         | 159/210 [00:19<00:06,  8.29it/s]
# Epoch 0:  95%|███████████████████████████▌ | 997/1048 [05:38<00:17,  2.94it/s, loss=2.64, v_num=feep]
# Validation DataLoader 0:  76%|████████████████████████████▏        | 160/210 [00:19<00:05,  8.35it/s]
# Epoch 0:  95%|███████████████████████████▌ | 998/1048 [05:38<00:16,  2.95it/s, loss=2.64, v_num=feep]
# Validation DataLoader 0:  77%|████████████████████████████▎        | 161/210 [00:19<00:05,  8.28it/s]
# Epoch 0:  95%|███████████████████████████▋ | 999/1048 [05:38<00:16,  2.95it/s, loss=2.64, v_num=feep]
# Validation DataLoader 0:  77%|████████████████████████████▌        | 162/210 [00:19<00:05,  8.17it/s]
# Epoch 0:  95%|██████████████████████████▋ | 1000/1048 [05:38<00:16,  2.95it/s, loss=2.64, v_num=feep]
# Validation DataLoader 0:  78%|████████████████████████████▋        | 163/210 [00:19<00:05,  8.17it/s]
# Epoch 0:  96%|██████████████████████████▋ | 1001/1048 [05:39<00:15,  2.95it/s, loss=2.64, v_num=feep]
# Validation DataLoader 0:  78%|████████████████████████████▉        | 164/210 [00:19<00:05,  8.18it/s]
# Epoch 0:  96%|██████████████████████████▊ | 1002/1048 [05:39<00:15,  2.95it/s, loss=2.64, v_num=feep]
# Validation DataLoader 0:  79%|█████████████████████████████        | 165/210 [00:20<00:05,  8.19it/s]
# Epoch 0:  96%|██████████████████████████▊ | 1003/1048 [05:39<00:15,  2.96it/s, loss=2.64, v_num=feep]
# Validation DataLoader 0:  79%|█████████████████████████████▏       | 166/210 [00:20<00:05,  8.07it/s]
# Epoch 0:  96%|██████████████████████████▊ | 1004/1048 [05:39<00:14,  2.96it/s, loss=2.64, v_num=feep]
# Validation DataLoader 0:  80%|█████████████████████████████▍       | 167/210 [00:20<00:05,  8.14it/s]
# Epoch 0:  96%|██████████████████████████▊ | 1005/1048 [05:39<00:14,  2.96it/s, loss=2.64, v_num=feep]
# Validation DataLoader 0:  80%|█████████████████████████████▌       | 168/210 [00:20<00:05,  8.09it/s]
# Epoch 0:  96%|██████████████████████████▉ | 1006/1048 [05:39<00:14,  2.96it/s, loss=2.64, v_num=feep]
# Validation DataLoader 0:  80%|█████████████████████████████▊       | 169/210 [00:20<00:05,  8.12it/s]
# Epoch 0:  96%|██████████████████████████▉ | 1007/1048 [05:39<00:13,  2.96it/s, loss=2.64, v_num=feep]
# Validation DataLoader 0:  81%|█████████████████████████████▉       | 170/210 [00:20<00:04,  8.03it/s]
# Epoch 0:  96%|██████████████████████████▉ | 1008/1048 [05:39<00:13,  2.97it/s, loss=2.64, v_num=feep]
# Validation DataLoader 0:  81%|██████████████████████████████▏      | 171/210 [00:20<00:04,  8.14it/s]
# Epoch 0:  96%|██████████████████████████▉ | 1009/1048 [05:40<00:13,  2.97it/s, loss=2.64, v_num=feep]
# Validation DataLoader 0:  82%|██████████████████████████████▎      | 172/210 [00:20<00:04,  8.23it/s]
# Epoch 0:  96%|██████████████████████████▉ | 1010/1048 [05:40<00:12,  2.97it/s, loss=2.64, v_num=feep]
# Validation DataLoader 0:  82%|██████████████████████████████▍      | 173/210 [00:20<00:04,  8.29it/s]
# Epoch 0:  96%|███████████████████████████ | 1011/1048 [05:40<00:12,  2.97it/s, loss=2.64, v_num=feep]
# Validation DataLoader 0:  83%|██████████████████████████████▋      | 174/210 [00:21<00:04,  8.31it/s]
# Epoch 0:  97%|███████████████████████████ | 1012/1048 [05:40<00:12,  2.97it/s, loss=2.64, v_num=feep]
# Validation DataLoader 0:  83%|██████████████████████████████▊      | 175/210 [00:21<00:04,  8.16it/s]
# Epoch 0:  97%|███████████████████████████ | 1013/1048 [05:40<00:11,  2.97it/s, loss=2.64, v_num=feep]
# Validation DataLoader 0:  84%|███████████████████████████████      | 176/210 [00:21<00:04,  8.22it/s]
# Epoch 0:  97%|███████████████████████████ | 1014/1048 [05:40<00:11,  2.98it/s, loss=2.64, v_num=feep]
# Validation DataLoader 0:  84%|███████████████████████████████▏     | 177/210 [00:21<00:04,  8.25it/s]
# Epoch 0:  97%|███████████████████████████ | 1015/1048 [05:40<00:11,  2.98it/s, loss=2.64, v_num=feep]
# Validation DataLoader 0:  85%|███████████████████████████████▎     | 178/210 [00:21<00:03,  8.31it/s]
# Epoch 0:  97%|███████████████████████████▏| 1016/1048 [05:40<00:10,  2.98it/s, loss=2.64, v_num=feep]
# Validation DataLoader 0:  85%|███████████████████████████████▌     | 179/210 [00:21<00:03,  8.19it/s]
# Epoch 0:  97%|███████████████████████████▏| 1017/1048 [05:41<00:10,  2.98it/s, loss=2.64, v_num=feep]
# Validation DataLoader 0:  86%|███████████████████████████████▋     | 180/210 [00:21<00:03,  8.25it/s]
# Epoch 0:  97%|███████████████████████████▏| 1018/1048 [05:41<00:10,  2.98it/s, loss=2.64, v_num=feep]
# Validation DataLoader 0:  86%|███████████████████████████████▉     | 181/210 [00:21<00:03,  8.23it/s]
# Epoch 0:  97%|███████████████████████████▏| 1019/1048 [05:41<00:09,  2.99it/s, loss=2.64, v_num=feep]
# Validation DataLoader 0:  87%|████████████████████████████████     | 182/210 [00:22<00:03,  8.25it/s]
# Epoch 0:  97%|███████████████████████████▎| 1020/1048 [05:41<00:09,  2.99it/s, loss=2.64, v_num=feep]
# Validation DataLoader 0:  87%|████████████████████████████████▏    | 183/210 [00:22<00:03,  8.18it/s]
# Epoch 0:  97%|███████████████████████████▎| 1021/1048 [05:41<00:09,  2.99it/s, loss=2.64, v_num=feep]
# Validation DataLoader 0:  88%|████████████████████████████████▍    | 184/210 [00:22<00:03,  8.24it/s]
# Epoch 0:  98%|███████████████████████████▎| 1022/1048 [05:41<00:08,  2.99it/s, loss=2.64, v_num=feep]
# Validation DataLoader 0:  88%|████████████████████████████████▌    | 185/210 [00:22<00:03,  8.31it/s]
# Epoch 0:  98%|███████████████████████████▎| 1023/1048 [05:41<00:08,  2.99it/s, loss=2.64, v_num=feep]
# Validation DataLoader 0:  89%|████████████████████████████████▊    | 186/210 [00:22<00:02,  8.34it/s]
# Epoch 0:  98%|███████████████████████████▎| 1024/1048 [05:41<00:08,  3.00it/s, loss=2.64, v_num=feep]
# Validation DataLoader 0:  89%|████████████████████████████████▉    | 187/210 [00:22<00:02,  8.24it/s]
# Epoch 0:  98%|███████████████████████████▍| 1025/1048 [05:42<00:07,  3.00it/s, loss=2.64, v_num=feep]
# Validation DataLoader 0:  90%|█████████████████████████████████    | 188/210 [00:22<00:02,  8.29it/s]
# Epoch 0:  98%|███████████████████████████▍| 1026/1048 [05:42<00:07,  3.00it/s, loss=2.64, v_num=feep]
# Validation DataLoader 0:  90%|█████████████████████████████████▎   | 189/210 [00:22<00:02,  8.33it/s]
# Epoch 0:  98%|███████████████████████████▍| 1027/1048 [05:42<00:06,  3.00it/s, loss=2.64, v_num=feep]
# Validation DataLoader 0:  90%|█████████████████████████████████▍   | 190/210 [00:23<00:02,  8.33it/s]
# Epoch 0:  98%|███████████████████████████▍| 1028/1048 [05:42<00:06,  3.00it/s, loss=2.64, v_num=feep]
# Validation DataLoader 0:  91%|█████████████████████████████████▋   | 191/210 [00:23<00:02,  8.24it/s]
# Epoch 0:  98%|███████████████████████████▍| 1029/1048 [05:42<00:06,  3.00it/s, loss=2.64, v_num=feep]
# Validation DataLoader 0:  91%|█████████████████████████████████▊   | 192/210 [00:23<00:02,  8.28it/s]
# Epoch 0:  98%|███████████████████████████▌| 1030/1048 [05:42<00:05,  3.01it/s, loss=2.64, v_num=feep]
# Validation DataLoader 0:  92%|██████████████████████████████████   | 193/210 [00:23<00:02,  8.34it/s]
# Epoch 0:  98%|███████████████████████████▌| 1031/1048 [05:42<00:05,  3.01it/s, loss=2.64, v_num=feep]
# Validation DataLoader 0:  92%|██████████████████████████████████▏  | 194/210 [00:23<00:01,  8.36it/s]
# Epoch 0:  98%|███████████████████████████▌| 1032/1048 [05:42<00:05,  3.01it/s, loss=2.64, v_num=feep]
# Validation DataLoader 0:  93%|██████████████████████████████████▎  | 195/210 [00:23<00:01,  8.38it/s]
# Epoch 0:  99%|███████████████████████████▌| 1033/1048 [05:42<00:04,  3.01it/s, loss=2.64, v_num=feep]
# Validation DataLoader 0:  93%|██████████████████████████████████▌  | 196/210 [00:23<00:01,  8.17it/s]
# Epoch 0:  99%|███████████████████████████▋| 1034/1048 [05:43<00:04,  3.01it/s, loss=2.64, v_num=feep]
# Validation DataLoader 0:  94%|██████████████████████████████████▋  | 197/210 [00:23<00:01,  8.24it/s]
# Epoch 0:  99%|███████████████████████████▋| 1035/1048 [05:43<00:04,  3.02it/s, loss=2.64, v_num=feep]
# Validation DataLoader 0:  94%|██████████████████████████████████▉  | 198/210 [00:24<00:01,  8.28it/s]
# Epoch 0:  99%|███████████████████████████▋| 1036/1048 [05:43<00:03,  3.02it/s, loss=2.64, v_num=feep]
# Validation DataLoader 0:  95%|███████████████████████████████████  | 199/210 [00:24<00:01,  8.27it/s]
# Epoch 0:  99%|███████████████████████████▋| 1037/1048 [05:43<00:03,  3.02it/s, loss=2.64, v_num=feep]
# Validation DataLoader 0:  95%|███████████████████████████████████▏ | 200/210 [00:24<00:01,  8.16it/s]
# Epoch 0:  99%|███████████████████████████▋| 1038/1048 [05:43<00:03,  3.02it/s, loss=2.64, v_num=feep]
# Validation DataLoader 0:  96%|███████████████████████████████████▍ | 201/210 [00:24<00:01,  8.16it/s]
# Epoch 0:  99%|███████████████████████████▊| 1039/1048 [05:43<00:02,  3.02it/s, loss=2.64, v_num=feep]
# Validation DataLoader 0:  96%|███████████████████████████████████▌ | 202/210 [00:24<00:00,  8.25it/s]
# Epoch 0:  99%|███████████████████████████▊| 1040/1048 [05:43<00:02,  3.02it/s, loss=2.64, v_num=feep]
# Validation DataLoader 0:  97%|███████████████████████████████████▊ | 203/210 [00:24<00:00,  8.34it/s]
# Epoch 0:  99%|███████████████████████████▊| 1041/1048 [05:43<00:02,  3.03it/s, loss=2.64, v_num=feep]
# Validation DataLoader 0:  97%|███████████████████████████████████▉ | 204/210 [00:24<00:00,  8.26it/s]
# Epoch 0:  99%|███████████████████████████▊| 1042/1048 [05:44<00:01,  3.03it/s, loss=2.64, v_num=feep]
# Validation DataLoader 0:  98%|████████████████████████████████████ | 205/210 [00:24<00:00,  8.34it/s]
# Epoch 0: 100%|███████████████████████████▊| 1043/1048 [05:44<00:01,  3.03it/s, loss=2.64, v_num=feep]
# Validation DataLoader 0:  98%|████████████████████████████████████▎| 206/210 [00:24<00:00,  8.40it/s]
# Epoch 0: 100%|███████████████████████████▉| 1044/1048 [05:44<00:01,  3.03it/s, loss=2.64, v_num=feep]
# Validation DataLoader 0:  99%|████████████████████████████████████▍| 207/210 [00:25<00:00,  8.43it/s]
# Epoch 0: 100%|███████████████████████████▉| 1045/1048 [05:44<00:00,  3.03it/s, loss=2.64, v_num=feep]
# Validation DataLoader 0:  99%|████████████████████████████████████▋| 208/210 [00:25<00:00,  8.27it/s]
# Epoch 0: 100%|███████████████████████████▉| 1046/1048 [05:44<00:00,  3.04it/s, loss=2.64, v_num=feep]
# Validation DataLoader 0: 100%|████████████████████████████████████▊| 209/210 [00:25<00:00,  8.34it/s]
# Epoch 0: 100%|███████████████████████████▉| 1047/1048 [05:44<00:00,  3.04it/s, loss=2.64, v_num=feep]
# Epoch 0: 100%|████████████████████████████| 1048/1048 [05:44<00:00,  3.04it/s, loss=2.64, v_num=feep]tensor(0.7789, device='cuda:0')
# Epoch 0: 100%|████████████████████████████| 1048/1048 [05:47<00:00,  3.02it/s, loss=2.64, v_num=feep]
# Epoch 1:  80%|███████████████████████▉      | 838/1048 [05:21<01:20,  2.61it/s, loss=2.4, v_num=feep]
# Validation: 0it [00:00, ?it/s]
# Validation:   0%|                                                            | 0/210 [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|                                               | 0/210 [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|▏                                      | 1/210 [00:00<00:32,  6.49it/s]
# Epoch 1:  80%|████████████████████████      | 839/1048 [05:22<01:20,  2.60it/s, loss=2.4, v_num=feep]
# Validation DataLoader 0:   1%|▎                                      | 2/210 [00:00<00:28,  7.28it/s]
# Epoch 1:  80%|████████████████████████      | 840/1048 [05:22<01:19,  2.61it/s, loss=2.4, v_num=feep]
# Validation DataLoader 0:   1%|▌                                      | 3/210 [00:00<00:27,  7.65it/s]
# Epoch 1:  80%|████████████████████████      | 841/1048 [05:22<01:19,  2.61it/s, loss=2.4, v_num=feep]
# Validation DataLoader 0:   2%|▋                                      | 4/210 [00:00<00:26,  7.75it/s]
# Epoch 1:  80%|████████████████████████      | 842/1048 [05:22<01:18,  2.61it/s, loss=2.4, v_num=feep]
# Validation DataLoader 0:   2%|▉                                      | 5/210 [00:00<00:25,  7.98it/s]
# Epoch 1:  80%|████████████████████████▏     | 843/1048 [05:22<01:18,  2.61it/s, loss=2.4, v_num=feep]
# Validation DataLoader 0:   3%|█                                      | 6/210 [00:00<00:25,  8.13it/s]
# Epoch 1:  81%|████████████████████████▏     | 844/1048 [05:22<01:17,  2.62it/s, loss=2.4, v_num=feep]
# Validation DataLoader 0:   3%|█▎                                     | 7/210 [00:00<00:24,  8.16it/s]
# Epoch 1:  81%|████████████████████████▏     | 845/1048 [05:22<01:17,  2.62it/s, loss=2.4, v_num=feep]
# Validation DataLoader 0:   4%|█▍                                     | 8/210 [00:01<00:25,  8.05it/s]
# Epoch 1:  81%|████████████████████████▏     | 846/1048 [05:22<01:17,  2.62it/s, loss=2.4, v_num=feep]
# Validation DataLoader 0:   4%|█▋                                     | 9/210 [00:01<00:24,  8.13it/s]
# Epoch 1:  81%|████████████████████████▏     | 847/1048 [05:23<01:16,  2.62it/s, loss=2.4, v_num=feep]
# Validation DataLoader 0:   5%|█▊                                    | 10/210 [00:01<00:24,  8.17it/s]
# Epoch 1:  81%|████████████████████████▎     | 848/1048 [05:23<01:16,  2.62it/s, loss=2.4, v_num=feep]
# Validation DataLoader 0:   5%|█▉                                    | 11/210 [00:01<00:24,  8.19it/s]
# Epoch 1:  81%|████████████████████████▎     | 849/1048 [05:23<01:15,  2.63it/s, loss=2.4, v_num=feep]
# Validation DataLoader 0:   6%|██▏                                   | 12/210 [00:01<00:24,  8.09it/s]
# Epoch 1:  81%|████████████████████████▎     | 850/1048 [05:23<01:15,  2.63it/s, loss=2.4, v_num=feep]
# Validation DataLoader 0:   6%|██▎                                   | 13/210 [00:01<00:24,  8.16it/s]
# Epoch 1:  81%|████████████████████████▎     | 851/1048 [05:23<01:14,  2.63it/s, loss=2.4, v_num=feep]
# Validation DataLoader 0:   7%|██▌                                   | 14/210 [00:01<00:23,  8.21it/s]
# Epoch 1:  81%|████████████████████████▍     | 852/1048 [05:23<01:14,  2.63it/s, loss=2.4, v_num=feep]
# Validation DataLoader 0:   7%|██▋                                   | 15/210 [00:01<00:23,  8.24it/s]
# Epoch 1:  81%|████████████████████████▍     | 853/1048 [05:23<01:14,  2.63it/s, loss=2.4, v_num=feep]
# Validation DataLoader 0:   8%|██▉                                   | 16/210 [00:01<00:23,  8.15it/s]
# Epoch 1:  81%|████████████████████████▍     | 854/1048 [05:23<01:13,  2.64it/s, loss=2.4, v_num=feep]
# Validation DataLoader 0:   8%|███                                   | 17/210 [00:02<00:23,  8.23it/s]
# Epoch 1:  82%|████████████████████████▍     | 855/1048 [05:24<01:13,  2.64it/s, loss=2.4, v_num=feep]
# Validation DataLoader 0:   9%|███▎                                  | 18/210 [00:02<00:23,  8.22it/s]
# ...
# Epoch 3:  93%|██████████████████████████▊  | 971/1048 [05:36<00:26,  2.88it/s, loss=2.51, v_num=feep]
# Validation DataLoader 0:  64%|███████████████████████▌             | 134/210 [00:16<00:09,  8.22it/s]
# Epoch 3:  93%|██████████████████████████▉  | 972/1048 [05:37<00:26,  2.88it/s, loss=2.51, v_num=feep]
# Validation DataLoader 0:  64%|███████████████████████▊             | 135/210 [00:16<00:09,  8.26it/s]
# Epoch 3:  93%|██████████████████████████▉  | 973/1048 [05:37<00:25,  2.89it/s, loss=2.51, v_num=feep]
# Validation DataLoader 0:  65%|███████████████████████▉             | 136/210 [00:16<00:08,  8.23it/s]
# Epoch 3:  93%|██████████████████████████▉  | 974/1048 [05:37<00:25,  2.89it/s, loss=2.51, v_num=feep]
# Validation DataLoader 0:  65%|████████████████████████▏            | 137/210 [00:16<00:08,  8.18it/s]
# Epoch 3:  93%|██████████████████████████▉  | 975/1048 [05:37<00:25,  2.89it/s, loss=2.51, v_num=feep]
# Validation DataLoader 0:  66%|████████████████████████▎            | 138/210 [00:16<00:08,  8.21it/s]
# Epoch 3:  93%|███████████████████████████  | 976/1048 [05:37<00:24,  2.89it/s, loss=2.51, v_num=feep]
# Validation DataLoader 0:  66%|████████████████████████▍            | 139/210 [00:16<00:08,  8.21it/s]
# Epoch 3:  93%|███████████████████████████  | 977/1048 [05:37<00:24,  2.89it/s, loss=2.51, v_num=feep]
# Validation DataLoader 0:  67%|████████████████████████▋            | 140/210 [00:17<00:08,  8.23it/s]
# Epoch 3:  93%|███████████████████████████  | 978/1048 [05:37<00:24,  2.89it/s, loss=2.51, v_num=feep]
# Validation DataLoader 0:  67%|████████████████████████▊            | 141/210 [00:17<00:08,  8.21it/s]
# Epoch 3:  93%|███████████████████████████  | 979/1048 [05:37<00:23,  2.90it/s, loss=2.51, v_num=feep]
# Validation DataLoader 0:  68%|█████████████████████████            | 142/210 [00:17<00:08,  8.25it/s]
# Epoch 3:  94%|███████████████████████████  | 980/1048 [05:38<00:23,  2.90it/s, loss=2.51, v_num=feep]
# Validation DataLoader 0:  68%|█████████████████████████▏           | 143/210 [00:17<00:08,  8.29it/s]
# Epoch 3:  94%|███████████████████████████▏ | 981/1048 [05:38<00:23,  2.90it/s, loss=2.51, v_num=feep]
# Validation DataLoader 0:  69%|█████████████████████████▎           | 144/210 [00:17<00:07,  8.28it/s]
# Epoch 3:  94%|███████████████████████████▏ | 982/1048 [05:38<00:22,  2.90it/s, loss=2.51, v_num=feep]
# Validation DataLoader 0:  69%|█████████████████████████▌           | 145/210 [00:17<00:07,  8.20it/s]
# Epoch 3:  94%|███████████████████████████▏ | 983/1048 [05:38<00:22,  2.90it/s, loss=2.51, v_num=feep]
# Validation DataLoader 0:  70%|█████████████████████████▋           | 146/210 [00:17<00:07,  8.20it/s]
# Epoch 3:  94%|███████████████████████████▏ | 984/1048 [05:38<00:22,  2.91it/s, loss=2.51, v_num=feep]
# Validation DataLoader 0:  70%|█████████████████████████▉           | 147/210 [00:17<00:07,  8.26it/s]
# Epoch 3:  94%|███████████████████████████▎ | 985/1048 [05:38<00:21,  2.91it/s, loss=2.51, v_num=feep]
# Validation DataLoader 0:  70%|██████████████████████████           | 148/210 [00:18<00:07,  8.26it/s]
# Epoch 3:  94%|███████████████████████████▎ | 986/1048 [05:38<00:21,  2.91it/s, loss=2.51, v_num=feep]
# Validation DataLoader 0:  71%|██████████████████████████▎          | 149/210 [00:18<00:07,  8.16it/s]
# Epoch 3:  94%|███████████████████████████▎ | 987/1048 [05:38<00:20,  2.91it/s, loss=2.51, v_num=feep]
# Validation DataLoader 0:  71%|██████████████████████████▍          | 150/210 [00:18<00:07,  8.20it/s]
# Epoch 3:  94%|███████████████████████████▎ | 988/1048 [05:39<00:20,  2.91it/s, loss=2.51, v_num=feep]
# Validation DataLoader 0:  72%|██████████████████████████▌          | 151/210 [00:18<00:07,  8.23it/s]
# Epoch 3:  94%|███████████████████████████▎ | 989/1048 [05:39<00:20,  2.92it/s, loss=2.51, v_num=feep]
# Validation DataLoader 0:  72%|██████████████████████████▊          | 152/210 [00:18<00:07,  8.27it/s]
# Epoch 3:  94%|███████████████████████████▍ | 990/1048 [05:39<00:19,  2.92it/s, loss=2.51, v_num=feep]
# Validation DataLoader 0:  73%|██████████████████████████▉          | 153/210 [00:18<00:06,  8.25it/s]
# Epoch 3:  95%|███████████████████████████▍ | 991/1048 [05:39<00:19,  2.92it/s, loss=2.51, v_num=feep]
# Validation DataLoader 0:  73%|███████████████████████████▏         | 154/210 [00:18<00:06,  8.08it/s]
# Epoch 3:  95%|███████████████████████████▍ | 992/1048 [05:39<00:19,  2.92it/s, loss=2.51, v_num=feep]
# Validation DataLoader 0:  74%|███████████████████████████▎         | 155/210 [00:18<00:06,  8.17it/s]
# Epoch 3:  95%|███████████████████████████▍ | 993/1048 [05:39<00:18,  2.92it/s, loss=2.51, v_num=feep]
# Validation DataLoader 0:  74%|███████████████████████████▍         | 156/210 [00:18<00:06,  8.23it/s]
# Epoch 3:  95%|███████████████████████████▌ | 994/1048 [05:39<00:18,  2.93it/s, loss=2.51, v_num=feep]
# Validation DataLoader 0:  75%|███████████████████████████▋         | 157/210 [00:19<00:06,  8.25it/s]
# Epoch 3:  95%|███████████████████████████▌ | 995/1048 [05:39<00:18,  2.93it/s, loss=2.51, v_num=feep]
# Validation DataLoader 0:  75%|███████████████████████████▊         | 158/210 [00:19<00:06,  8.15it/s]
# Epoch 3:  95%|███████████████████████████▌ | 996/1048 [05:40<00:17,  2.93it/s, loss=2.51, v_num=feep]
# Validation DataLoader 0:  76%|████████████████████████████         | 159/210 [00:19<00:06,  8.21it/s]
# Epoch 3:  95%|███████████████████████████▌ | 997/1048 [05:40<00:17,  2.93it/s, loss=2.51, v_num=feep]
# Validation DataLoader 0:  76%|████████████████████████████▏        | 160/210 [00:19<00:06,  8.23it/s]
# Epoch 3:  95%|███████████████████████████▌ | 998/1048 [05:40<00:17,  2.93it/s, loss=2.51, v_num=feep]
# Validation DataLoader 0:  77%|████████████████████████████▎        | 161/210 [00:19<00:05,  8.24it/s]
# Epoch 3:  95%|███████████████████████████▋ | 999/1048 [05:40<00:16,  2.93it/s, loss=2.51, v_num=feep]
# Validation DataLoader 0:  77%|████████████████████████████▌        | 162/210 [00:19<00:05,  8.11it/s]
# Epoch 3:  95%|██████████████████████████▋ | 1000/1048 [05:40<00:16,  2.94it/s, loss=2.51, v_num=feep]
# Validation DataLoader 0:  78%|████████████████████████████▋        | 163/210 [00:19<00:05,  8.17it/s]
# Epoch 3:  96%|██████████████████████████▋ | 1001/1048 [05:40<00:15,  2.94it/s, loss=2.51, v_num=feep]
# Validation DataLoader 0:  78%|████████████████████████████▉        | 164/210 [00:19<00:05,  8.21it/s]
# Epoch 3:  96%|██████████████████████████▊ | 1002/1048 [05:40<00:15,  2.94it/s, loss=2.51, v_num=feep]
# Validation DataLoader 0:  79%|█████████████████████████████        | 165/210 [00:20<00:05,  8.26it/s]
# Epoch 3:  96%|██████████████████████████▊ | 1003/1048 [05:40<00:15,  2.94it/s, loss=2.51, v_num=feep]
# Validation DataLoader 0:  79%|█████████████████████████████▏       | 166/210 [00:20<00:05,  8.13it/s]
# Epoch 3:  96%|██████████████████████████▊ | 1004/1048 [05:41<00:14,  2.94it/s, loss=2.51, v_num=feep]
# Validation DataLoader 0:  80%|█████████████████████████████▍       | 167/210 [00:20<00:05,  8.20it/s]
# Epoch 3:  96%|██████████████████████████▊ | 1005/1048 [05:41<00:14,  2.95it/s, loss=2.51, v_num=feep]
# Validation DataLoader 0:  80%|█████████████████████████████▌       | 168/210 [00:20<00:05,  8.23it/s]
# Epoch 3:  96%|██████████████████████████▉ | 1006/1048 [05:41<00:14,  2.95it/s, loss=2.51, v_num=feep]
# Validation DataLoader 0:  80%|█████████████████████████████▊       | 169/210 [00:20<00:04,  8.26it/s]
# Epoch 3:  96%|██████████████████████████▉ | 1007/1048 [05:41<00:13,  2.95it/s, loss=2.51, v_num=feep]
# Validation DataLoader 0:  81%|█████████████████████████████▉       | 170/210 [00:20<00:04,  8.14it/s]
# Epoch 3:  96%|██████████████████████████▉ | 1008/1048 [05:41<00:13,  2.95it/s, loss=2.51, v_num=feep]
# Validation DataLoader 0:  81%|██████████████████████████████▏      | 171/210 [00:20<00:04,  8.19it/s]
# Epoch 3:  96%|██████████████████████████▉ | 1009/1048 [05:41<00:13,  2.95it/s, loss=2.51, v_num=feep]
# Validation DataLoader 0:  82%|██████████████████████████████▎      | 172/210 [00:20<00:04,  8.29it/s]
# Epoch 3:  96%|██████████████████████████▉ | 1010/1048 [05:41<00:12,  2.96it/s, loss=2.51, v_num=feep]
# Validation DataLoader 0:  82%|██████████████████████████████▍      | 173/210 [00:21<00:04,  8.35it/s]
# Epoch 3:  96%|███████████████████████████ | 1011/1048 [05:41<00:12,  2.96it/s, loss=2.51, v_num=feep]
# Validation DataLoader 0:  83%|██████████████████████████████▋      | 174/210 [00:21<00:04,  8.40it/s]
# Epoch 3:  97%|███████████████████████████ | 1012/1048 [05:41<00:12,  2.96it/s, loss=2.51, v_num=feep]
# Validation DataLoader 0:  83%|██████████████████████████████▊      | 175/210 [00:21<00:04,  8.20it/s]
# Epoch 3:  97%|███████████████████████████ | 1013/1048 [05:42<00:11,  2.96it/s, loss=2.51, v_num=feep]
# Validation DataLoader 0:  84%|███████████████████████████████      | 176/210 [00:21<00:04,  8.30it/s]
# Epoch 3:  97%|███████████████████████████ | 1014/1048 [05:42<00:11,  2.96it/s, loss=2.51, v_num=feep]
# Validation DataLoader 0:  84%|███████████████████████████████▏     | 177/210 [00:21<00:03,  8.36it/s]
# Epoch 3:  97%|███████████████████████████ | 1015/1048 [05:42<00:11,  2.96it/s, loss=2.51, v_num=feep]
# Validation DataLoader 0:  85%|███████████████████████████████▎     | 178/210 [00:21<00:03,  8.30it/s]
# Epoch 3:  97%|███████████████████████████▏| 1016/1048 [05:42<00:10,  2.97it/s, loss=2.51, v_num=feep]
# Validation DataLoader 0:  85%|███████████████████████████████▌     | 179/210 [00:21<00:03,  8.14it/s]
# Epoch 3:  97%|███████████████████████████▏| 1017/1048 [05:42<00:10,  2.97it/s, loss=2.51, v_num=feep]
# Validation DataLoader 0:  86%|███████████████████████████████▋     | 180/210 [00:21<00:03,  8.22it/s]
# Epoch 3:  97%|███████████████████████████▏| 1018/1048 [05:42<00:10,  2.97it/s, loss=2.51, v_num=feep]
# Validation DataLoader 0:  86%|███████████████████████████████▉     | 181/210 [00:22<00:03,  8.24it/s]
# Epoch 3:  97%|███████████████████████████▏| 1019/1048 [05:42<00:09,  2.97it/s, loss=2.51, v_num=feep]
# Validation DataLoader 0:  87%|████████████████████████████████     | 182/210 [00:22<00:03,  8.28it/s]
# Epoch 3:  97%|███████████████████████████▎| 1020/1048 [05:42<00:09,  2.97it/s, loss=2.51, v_num=feep]
# Validation DataLoader 0:  87%|████████████████████████████████▏    | 183/210 [00:22<00:03,  8.17it/s]
# Epoch 3:  97%|███████████████████████████▎| 1021/1048 [05:43<00:09,  2.98it/s, loss=2.51, v_num=feep]
# Validation DataLoader 0:  88%|████████████████████████████████▍    | 184/210 [00:22<00:03,  8.26it/s]
# Epoch 3:  98%|███████████████████████████▎| 1022/1048 [05:43<00:08,  2.98it/s, loss=2.51, v_num=feep]
# Validation DataLoader 0:  88%|████████████████████████████████▌    | 185/210 [00:22<00:02,  8.33it/s]
# Epoch 3:  98%|███████████████████████████▎| 1023/1048 [05:43<00:08,  2.98it/s, loss=2.51, v_num=feep]
# Validation DataLoader 0:  89%|████████████████████████████████▊    | 186/210 [00:22<00:02,  8.39it/s]
# Epoch 3:  98%|███████████████████████████▎| 1024/1048 [05:43<00:08,  2.98it/s, loss=2.51, v_num=feep]
# Validation DataLoader 0:  89%|████████████████████████████████▉    | 187/210 [00:22<00:02,  8.26it/s]
# Epoch 3:  98%|███████████████████████████▍| 1025/1048 [05:43<00:07,  2.98it/s, loss=2.51, v_num=feep]
# Validation DataLoader 0:  90%|█████████████████████████████████    | 188/210 [00:22<00:02,  8.34it/s]
# Epoch 3:  98%|███████████████████████████▍| 1026/1048 [05:43<00:07,  2.99it/s, loss=2.51, v_num=feep]
# Validation DataLoader 0:  90%|█████████████████████████████████▎   | 189/210 [00:22<00:02,  8.38it/s]
# Epoch 3:  98%|███████████████████████████▍| 1027/1048 [05:43<00:07,  2.99it/s, loss=2.51, v_num=feep]
# Validation DataLoader 0:  90%|█████████████████████████████████▍   | 190/210 [00:23<00:02,  8.41it/s]
# Epoch 3:  98%|███████████████████████████▍| 1028/1048 [05:43<00:06,  2.99it/s, loss=2.51, v_num=feep]
# Validation DataLoader 0:  91%|█████████████████████████████████▋   | 191/210 [00:23<00:02,  8.30it/s]
# Epoch 3:  98%|███████████████████████████▍| 1029/1048 [05:44<00:06,  2.99it/s, loss=2.51, v_num=feep]
# Validation DataLoader 0:  91%|█████████████████████████████████▊   | 192/210 [00:23<00:02,  8.36it/s]
# Epoch 3:  98%|███████████████████████████▌| 1030/1048 [05:44<00:06,  2.99it/s, loss=2.51, v_num=feep]
# Validation DataLoader 0:  92%|██████████████████████████████████   | 193/210 [00:23<00:02,  8.39it/s]
# Epoch 3:  98%|███████████████████████████▌| 1031/1048 [05:44<00:05,  2.99it/s, loss=2.51, v_num=feep]
# Validation DataLoader 0:  92%|██████████████████████████████████▏  | 194/210 [00:23<00:01,  8.42it/s]
# Epoch 3:  98%|███████████████████████████▌| 1032/1048 [05:44<00:05,  3.00it/s, loss=2.51, v_num=feep]
# Validation DataLoader 0:  93%|██████████████████████████████████▎  | 195/210 [00:23<00:01,  8.39it/s]
# Epoch 3:  99%|███████████████████████████▌| 1033/1048 [05:44<00:05,  3.00it/s, loss=2.51, v_num=feep]
# Validation DataLoader 0:  93%|██████████████████████████████████▌  | 196/210 [00:23<00:01,  8.22it/s]
# Epoch 3:  99%|███████████████████████████▋| 1034/1048 [05:44<00:04,  3.00it/s, loss=2.51, v_num=feep]
# Validation DataLoader 0:  94%|██████████████████████████████████▋  | 197/210 [00:23<00:01,  8.21it/s]
# Epoch 3:  99%|███████████████████████████▋| 1035/1048 [05:44<00:04,  3.00it/s, loss=2.51, v_num=feep]
# Validation DataLoader 0:  94%|██████████████████████████████████▉  | 198/210 [00:24<00:01,  8.22it/s]
# Epoch 3:  99%|███████████████████████████▋| 1036/1048 [05:44<00:03,  3.00it/s, loss=2.51, v_num=feep]
# Validation DataLoader 0:  95%|███████████████████████████████████  | 199/210 [00:24<00:01,  8.23it/s]
# Epoch 3:  99%|███████████████████████████▋| 1037/1048 [05:44<00:03,  3.01it/s, loss=2.51, v_num=feep]
# Validation DataLoader 0:  95%|███████████████████████████████████▏ | 200/210 [00:24<00:01,  8.10it/s]
# Epoch 3:  99%|███████████████████████████▋| 1038/1048 [05:45<00:03,  3.01it/s, loss=2.51, v_num=feep]
# Validation DataLoader 0:  96%|███████████████████████████████████▍ | 201/210 [00:24<00:01,  8.20it/s]
# Epoch 3:  99%|███████████████████████████▊| 1039/1048 [05:45<00:02,  3.01it/s, loss=2.51, v_num=feep]
# Validation DataLoader 0:  96%|███████████████████████████████████▌ | 202/210 [00:24<00:00,  8.29it/s]
# Epoch 3:  99%|███████████████████████████▊| 1040/1048 [05:45<00:02,  3.01it/s, loss=2.51, v_num=feep]
# Validation DataLoader 0:  97%|███████████████████████████████████▊ | 203/210 [00:24<00:00,  8.35it/s]
# Epoch 3:  99%|███████████████████████████▊| 1041/1048 [05:45<00:02,  3.01it/s, loss=2.51, v_num=feep]
# Validation DataLoader 0:  97%|███████████████████████████████████▉ | 204/210 [00:24<00:00,  8.27it/s]
# Epoch 3:  99%|███████████████████████████▊| 1042/1048 [05:45<00:01,  3.02it/s, loss=2.51, v_num=feep]
# Validation DataLoader 0:  98%|████████████████████████████████████ | 205/210 [00:24<00:00,  8.35it/s]
# Epoch 3: 100%|███████████████████████████▊| 1043/1048 [05:45<00:01,  3.02it/s, loss=2.51, v_num=feep]
# Validation DataLoader 0:  98%|████████████████████████████████████▎| 206/210 [00:25<00:00,  8.39it/s]
# Epoch 3: 100%|███████████████████████████▉| 1044/1048 [05:45<00:01,  3.02it/s, loss=2.51, v_num=feep]
# Validation DataLoader 0:  99%|████████████████████████████████████▍| 207/210 [00:25<00:00,  8.43it/s]
# Epoch 3: 100%|███████████████████████████▉| 1045/1048 [05:45<00:00,  3.02it/s, loss=2.51, v_num=feep]
# Validation DataLoader 0:  99%|████████████████████████████████████▋| 208/210 [00:25<00:00,  8.32it/s]
# Epoch 3: 100%|███████████████████████████▉| 1046/1048 [05:46<00:00,  3.02it/s, loss=2.51, v_num=feep]
# Validation DataLoader 0: 100%|████████████████████████████████████▊| 209/210 [00:25<00:00,  8.38it/s]
# Epoch 3: 100%|███████████████████████████▉| 1047/1048 [05:46<00:00,  3.02it/s, loss=2.51, v_num=feep]
# Epoch 3: 100%|████████████████████████████| 1048/1048 [05:46<00:00,  3.03it/s, loss=2.51, v_num=feep]tensor(0.6970, device='cuda:0')
# Epoch 3: 100%|████████████████████████████| 1048/1048 [05:48<00:00,  3.01it/s, loss=2.51, v_num=feep]
# Epoch 3: 100%|████████████████████████████| 1048/1048 [06:02<00:00,  2.89it/s, loss=2.51, v_num=feep]

# %%
wandb.finish()
# Out:
# Waiting for W&B process to finish... <strong style="color:green">(success).</strong>
# <style>
#     table.wandb td:nth-child(1) { padding: 0 10px; text-align: left ; width: auto;} td:nth-child(2) {text-align: left ; width: 100%}
#     .wandb-row { display: flex; flex-direction: row; flex-wrap: wrap; justify-content: flex-start; width: 100% }
#     .wandb-col { display: flex; flex-direction: column; flex-basis: 100%; flex: 1; padding: 10px; }
#     </style>
# <div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>epoch</td><td>▁▁▁▁▁▁▁▁▁▃▃▃▃▃▃▃▃▃▆▆▆▆▆▆▆▆▆▆█████████</td></tr><tr><td>example_loss</td><td>█▃▃▁</td></tr><tr><td>train_classes_loss</td><td>█▄█▆▄▅▆▃▃▃▃▆▄▄▄▄▂█▆▆▄▃▃▃▂▃▄▅▃▆▃▂▁</td></tr><tr><td>train_examples_loss</td><td>▆█▃▃▅▆▂▃▄▃▆▅▅▄▃▂▂▃▄▄▃▄▃▅▂▁▂▃▃▃▁▃▇</td></tr><tr><td>train_scores_loss</td><td>▆█▃▄▅▅▃▃▄▃▃▅▅▆▄▂▁▃▅▅▄▆▃▅▂▁▂▅▄▂▂▁▆</td></tr><tr><td>train_total_loss</td><td>█▇▆▅▅▆▄▃▄▃▄▆▅▅▄▂▁▆▅▆▄▄▃▄▁▁▂▄▃▄▁▁▄</td></tr><tr><td>trainer/global_step</td><td>▁▁▁▂▂▂▂▃▃▃▃▃▃▄▄▄▄▄▄▅▅▅▅▆▆▆▆▆▆▇▇▇▇▇███</td></tr><tr><td>val_class_loss</td><td>█▄▁▁</td></tr><tr><td>val_loss</td><td>█▅▃▁</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>epoch</td><td>3</td></tr><tr><td>example_loss</td><td>0.69697</td></tr><tr><td>train_classes_loss</td><td>0.54289</td></tr><tr><td>train_examples_loss</td><td>1.13402</td></tr><tr><td>train_scores_loss</td><td>1.01846</td></tr><tr><td>train_total_loss</td><td>2.69538</td></tr><tr><td>trainer/global_step</td><td>3351</td></tr><tr><td>val_class_loss</td><td>0.96168</td></tr><tr><td>val_loss</td><td>0.66932</td></tr></table><br/></div></div>
# Synced <strong style="color:#cdcd00">apricot-puddle-104</strong>: <a href="https://wandb.ai/darek/fbck/runs/18yjfeep" target="_blank">https://wandb.ai/darek/fbck/runs/18yjfeep</a><br/>Synced 7 W&B file(s), 0 media file(s), 0 artifact file(s) and 1 other file(s)
# Find logs at: <code>./wandb/run-20220726_213442-18yjfeep/logs</code>
